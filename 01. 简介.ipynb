# %% [markdown]
# # 简介

# %% [markdown]
# ## 1. 深度学习
#
# <img src="./images/scope.jpg" />
#
# ## 2. TensorFlow
#
# <img src="./images/tensorflow.svg" width="200"/>
#
# 2015年11月9日发行beta版本，TensorFlow支持多种客户端语言下的安装和运行。当前最新版本1.14.0， 2.0目前处于beta版状态。
# 绑定完成的语言有Python、JavaScript、C++、Go和Java，移动端 TensorFlow Lite、TensorFlow Lite on iOS。
#
# > TensorFlow主要支持静态计算图的形式，计算图的结构比较直观，但是在调试过程中十分复杂与麻烦，一些错误更加难以发。但是2017年底发布了动态图机制Eager Execution，加入对于动态计算图的支持，但是目前依旧采用原有的静态计算图形式为主。 2.0版本默认启用Eager Execution
#
# 分：CPU版本和GPU版, 硬件可选: Nvidia Tesla显卡
#
# - [TensorFlow中文官网](https://tensorflow.google.cn/)
#
# - [Tensorflow趋势](https://trends.google.com/trends/explore?date=today%205-y&q=TensorFlow,Theano,xgboost,PyTorch,scikit-learn)
# > 16年至今在Kaggle竞赛上，参赛团队使用的两大工具:
#     1. 浅层学习：[梯度提升机xgboost](https://xgboost.ai/)
#     2. 深度学习：Keras, 同时Keras底层默认使用Tensorflow, 同时支持 Theano和CNTK
#
# - `机器学习`及`numpy`对python的影响 [Python & 编程语言排行](https://www.tiobe.com/tiobe-index/)
#
# - [Keras是什么？](https://keras.io/)
# > 别再纠结是学Keras还是TensorFlow
#
# - [Kaggle](https://www.kaggle.com/)
#
#
# ## 3. 两个概念
#
# > 了解就可以了，不需要深入
#
# - Tensor(张量)
#
# > [什么是张量？](https://www.youtube.com/watch?v=f5liqUk0ZTw)
#
# - Entropy（熵）
#
# > [什么是熵？](https://www.youtube.com/watch?v=uQSoaiubuA0)
#
#
# ## 4. 开发观念转变
#
# - 编码实现规则
# - 样本数据倒推规则
#
# <img src="./images/diff.png" />
#
# <img src="./images/flow.png" />
#
# ## 5. Neural Networks（神经网络）
#
# <img src="./images/hidden_layer.jpg" />
#
# > 链式几何变换、深度可微模型、分层表示学习、层级表示学习
#
# <img src="./images/trainning.gif" />
#
# ## 6. 和人类大脑神经没有任何关系
#
# - 不具备抽象能力
#
# <img src="./images/smile.png" />
#
# <img src="./images/smile2.png" />
#
# - 不具备推理能力
#
#
# ## 7. 能解决什么问题？
#
# - 二分类问题， 如：情感分析等
# - 多分类问题， 如: 打标签，手势识别，图像识别等
# - 回归问题， 如：房价预测、油耗预测等
#
#
# ## 8. 对数学功底的要求
#
# - 无要求
# - 非常高
#
#
# ## 9. 完整的程序组成
#
# - 准备数据
# - 构建模型
# - 编译模型
# - 训练模型
# - 评估模型
# - 保存模型
# - 使用模型
#
# > 主要使用keras高阶api完成
#
#
# ## 10. 环境安装
#
# ### 10.1 [官方pip安装](https://tensorflow.google.cn/install/pip) ,  `强烈推荐使用virtualenv `
#
# 安装使用到的第三方Python库
#
#
# ```shell
# $ pip install pandas seaborn matplotlib
# ```
#
# > 补充: pip设置阿里源，可提高pip包安装速速, 通过下面的方式设置，假如没有.pip目录，手动创建一下， 该方法同样适用于Docker方式
#
# ```shell
# $ vi ~/.pip/pip.conf
# ```
#
# 将下面的内容黏贴到pip.conf
#
# ```text
# [global]
# trusted-host =  mirrors.aliyun.com
# index-url = https://mirrors.aliyun.com/pypi/simple
# ```
#
# ### 10.2 使用docker方式运行
#
# 本教程使用镜像`tensorflow/tensorflow:latest-py3-jupyter`，docker容器方式运行，容器具备`tensorflow`和`jupyter`功能
#
# #### 10.2.1 [docker安装](https://docs.docker.com/install/linux/docker-ce/centos/)
#
# #### 10.2.2 运行容器
# ```shell
# $ docker run -d -v /data/jupyter:/tf -p 8888:8888 -p 6006:6006 --name 'tf-py3-jupyter' tensorflow/tensorflow:latest-py3-jupyter
# ```
#
# 容器启动成功之后，看一下jupyter生成的token
#
# ```shell
# $ docker logs tf-py3-jupyter
# ```
# <img src="./images/docker.png" />
#
#
# #### 10.2.3 进入容器安装第三方包
#
# 通过下面的命令可进入容器
#
# ```shell
# $ docker run -it tf-py3-jupyter /bin/sh
# $ pip install pandas seaborn matplotlib
# ```
#
# #### 10.2.4 打开jupyter notebook
#
# http://xxx.xxx.xxx.xxx:8888/?token=8d76d4031aad3b5a8b1cdaf81abe2480f5ab782b3d64715a
#
# NOTE： token的具体值，以实际情况为准
#
# #### 10.2.5. 笔记本地址
#
# [https://github.com/wujjpp/ml-based-on-tensorflow](https://github.com/wujjpp/ml-based-on-tensorflow)
#
# 在/data/jupyter/目录下创建`results`, `saved_models`两个目录
#
# <img src="./images/github_url.png" />
# <center>扫一扫保存笔记本地址</center>
