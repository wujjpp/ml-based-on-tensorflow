# %% [markdown]
# # 总结

# %% [markdown]
# ## 1. 层
#
#
# <table style="width:100%">
#     <thead>
#         <tr>
#             <th style="text-align: left;">类型</th>
#             <th style="text-align: left;">名称</th>
#             <th style="text-align: left;">说明</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td style="text-align: left;">tf.keras.layers.Dense </td>
#             <td style="text-align: left;">全连接层</td>
#             <td style="text-align: left;">向量数据</td>
#         </tr>
#         <tr>
#             <td style="text-align: left;">tf.keras.layers.SeparableConv2D</td>
#             <td style="text-align: left;">深度可分离2D卷积层</td>
#             <td style="text-align: left;">图像数据，与2D池化层配合使用 </td>
#         </tr>
#         <tr>
#             <td style="text-align: left;">tf.keras.layers.SeparableConv1D</td>
#             <td style="text-align: left;">深度可分离1D卷积层</td>
#             <td style="text-align: left;">声音数据（波形），与1D池化层配合使用 </td>
#         </tr>
#         <tr>
#             <td style="text-align: left;">|tf.keras.layers.Conv2D </td>
#             <td style="text-align: left;">2D卷积层</td>
#             <td style="text-align: left;">图像数据，与2D池化层配合使用 </td>
#         </tr>
#         <tr>
#             <td style="text-align: left;">tf.keras.layers.Conv1D </td>
#             <td style="text-align: left;">1D卷积层</td>
#             <td style="text-align: left;">声音数据（波形），与1D池化层配合使用 </td>
#         </tr>
#         <tr>
#             <td style="text-align: left;">tf.keras.layers.Conv3D</td>
#             <td style="text-align: left;">3D卷积层</td>
#             <td style="text-align: left;">视频数据，与3D池化层配合使用</td>
#         </tr>
#         <tr>
#             <td style="text-align: left;">tf.keras.layers.MaxPooling2D</td>
#             <td style="text-align: left;">2D池化层</td>
#             <td style="text-align: left;">与2D卷积层配合使用</td>
#         </tr>
#         <tr>
#             <td style="text-align: left;">tf.keras.layers.MaxPooling1D</td>
#             <td style="text-align: left;">1D池化层</td>
#             <td style="text-align: left;">与1D卷积层配合使用</td>
#         </tr>
#         <tr>
#             <td style="text-align: left;">tf.keras.layers.MaxPooling3D</td>
#             <td style="text-align: left;">3D池化层</td>
#             <td style="text-align: left;">与3D卷积层配合使用</td>
#         </tr>
#         <tr>
#             <td style="text-align: left;">tf.keras.layers.Embedding</td>
#             <td style="text-align: left;">词嵌入</td>
#             <td style="text-align: left;">一般用于文本处理，做输入层使用</td>
#         </tr>
#         <tr>
#             <td style="text-align: left;">tf.keras.layers.RNN</td>
#             <td style="text-align: left;"><a href='https://baike.baidu.com/item/%E5%BE%AA%E7%8E%AF%E7%A5%9E%E7%BB%8F%E7%BD%91%E7%BB%9C/23199490' target="_blank">循环神经网络</a></td>
#             <td style="text-align: left;">时间序列数据，前后相关</td>
#         </tr>
#         <tr>
#             <td style="text-align: left;">tf.keras.layers.LSTM</td>
#             <td style="text-align: left;"><a href='https://baike.baidu.com/item/%E9%95%BF%E7%9F%AD%E6%9C%9F%E8%AE%B0%E5%BF%86%E4%BA%BA%E5%B7%A5%E7%A5%9E%E7%BB%8F%E7%BD%91%E7%BB%9C/17541107?fromtitle=LSTM&fromid=17541102&fr=aladdin#ref_[2]_17620638' target='_blank'>长短期记忆网络</a></td>
#             <td style="text-align: left;">时间序列数据，前后相关</td>
#         </tr>
#         <tr>
#             <td style="text-align: left;">tf.keras.layers.Flatten </td>
#             <td style="text-align: left;">展平</td>
#             <td style="text-align: left;">用于将多维数据转化成一维数据，作为池化层和全连接层桥梁</td>
#         </tr>
#         <tr>
#             <td style="text-align: left;">tf.keras.layers.GlobalAveragePooling2D</td>
#             <td style="text-align: left;">-</td>
#             <td style="text-align: left;">可以放在池化层和全连接层之间</td>
#         </tr>
#         <tr>
#             <td style="text-align: left;">tf.keras.layers.GlobalAveragePooling1D</td>
#             <td style="text-align: left;">-</td>
#             <td style="text-align: left;">可以放在池化层和全连接层之间</td>
#         </tr>
#         <tr>
#             <td style="text-align: left;">tf.keras.layers.GlobalAveragePooling3D</td>
#             <td style="text-align: left;">-</td>
#             <td style="text-align: left;">可以放在池化层和全连接层之间</td>
#         </tr>
#         <tr>
#             <td style="text-align: left;">tf.keras.layers.GlobalMaxPool1D</td>
#             <td style="text-align: left;">-</td>
#             <td style="text-align: left;">可以放在池化层和全连接层之间</td>
#         </tr>
#         <tr>
#             <td style="text-align: left;">tf.keras.layers.GlobalMaxPool2D</td>
#             <td style="text-align: left;">-</td>
#             <td style="text-align: left;">可以放在池化层和全连接层之间</td>
#         </tr>
#         <tr>
#             <td style="text-align: left;">tf.keras.layers.GlobalMaxPool3D</td>
#             <td style="text-align: left;">-</td>
#             <td style="text-align: left;">可以放在池化层和全连接层之间</td>
#         </tr>
#     </tbody>
# </table>
#
#
# 关于最后一层网络（输出层）：
#
# - 任何类型网络最后一层 `一定` 是全连接层（tf.keras.layers.Dense）
# - 二分类问题输出维度一定是 `1`
# - 多分类问题输出维度是 `类别总数`
# - 回归问题输出维度一定是 `1`
#     1. 回归到任意值： `不带任何激活函数`
#     2. 回归到0~1范围内的值： 激活函数一定是sigmoid
#
# sigmoid: 将任意值压缩到 0 到 1 之前

# %% [markdown]
# ## 2. 损失函数&最后一层激活
#
# <table style="width:100%">
#     <thead>
#         <tr>
#             <th style="text-align: left;">问题类型</th>
#             <th style="text-align: left;">最后一层激活</th>
#             <th style="text-align: left;">损失函数</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td style="text-align: left;">二分类问题，标签数值一定是0或者1</td>
#             <td style="text-align: left;">tf.keras.activations.sigmoid</td>
#             <td style="text-align: left;">binary_crossentropy</td>
#         </tr>
#         <tr>
#             <td style="text-align: left;">多分类、单标签问题</td>
#             <td style="text-align: left;">tf.keras.activations.softmax</td>
#             <td style="text-align: left;">
#                 标签是One-Hot格式：tf.keras.losses.categorical_crossentropy <br />
#                标签是数值: tf.keras.losses.sparse_categorical_crossentropy
#             </td>
#         </tr>
#         <tr>
#             <td style="text-align: left;">多分类、多标签问题，标签一定是K-Hot格式</td>
#             <td style="text-align: left;">tf.keras.activations.sigmoid</td>
#             <td style="text-align: left;">
#                 tf.keras.losses.binary_crossentropy
#             </td>
#         </tr>
#         <tr>
#             <td style="text-align: left;">回归到任意值</td>
#             <td style="text-align: left;">无</td>
#             <td style="text-align: left;">tf.keras.losses.mse</td>
#         </tr>
#         <tr>
#             <td style="text-align: left;">回归到0~1范围内的值</td>
#             <td style="text-align: left;">tf.keras.activations.sigmoid</td>
#             <td style="text-align: left;">tf.keras.losses.mse或tf.keras.losses.binary_crossentropy</td>
#         </tr>
#     </tbody>
# </table>
#
#
# - 什么是One-Hot？
# > 比如总共有3个分类， 类别一：用数组[1, 0, 0]表示, 类别二：用数组[0, 1, 0]表示，类别三：用数组[0, 0, 1]表示。卷积神经网络就是采用这种编码来表示单标签的
#
# - 什么是K-Hot？
# > 比如总共有3个分类， 样本一属于类别1和类别2，那么用数组[1, 1, 0]表示
#
# - 好多名字？
#     1. tf.compat.v1.keras.losses.MSE
#     2. tf.compat.v1.keras.losses.mean_squared_error
#     3. tf.compat.v1.keras.losses.mse
#     4. tf.compat.v1.keras.metrics.MSE
#     5. tf.compat.v1.keras.metrics.mean_squared_error
#     6. tf.compat.v1.keras.metrics.mse
#     7. tf.compat.v2.keras.losses.MSE
#     8. tf.compat.v2.keras.losses.mean_squared_error
#     9. tf.compat.v2.keras.losses.mse
#     10. tf.compat.v2.keras.metrics.MSE
#     11. tf.compat.v2.keras.metrics.mean_squared_error
#     12. tf.compat.v2.keras.metrics.mse
#     13. tf.compat.v2.losses.MSE
#     14. tf.compat.v2.losses.mean_squared_error
#     15. tf.compat.v2.losses.mse
#     16. tf.compat.v2.metrics.MSE
#     17. tf.compat.v2.metrics.mean_squared_error
#     18. tf.compat.v2.metrics.mse
#     19. tf.keras.losses.MSE
#     20. tf.keras.losses.mean_squared_error
#     21. tf.keras.losses.mse
#     22. tf.keras.metrics.MSE
#     23. tf.keras.metrics.mean_squared_error
#     24. tf.keras.metrics.mse

# %% [markdown]
# ## 3. 优化器
#
# 目前用到的优化器：(优化器选择和需要解决问题类型关系不是很大，当发生无法收敛的时候，最后考虑调整优化器)
#
# - tf.keras.optimizers.Adam
# - tf.keras.optimizers.RMSprop
#
# <img src="./images/optimizers.gif" width="60%"/>

# %% [markdown]
# ## 4. 激活器
#
# ### 4.1 tf.keras.activations.relu 线性整流函数
# <img src="./images/relu.png" />
# <center>
#     f(x) = max(0, x)
# </center>
#
# 主要用于全连接层(tf.keras.layser.Dense)（非最后一层）
#
# ### 4.2 tf.keras.activations.softmax
# 主要用在 `单标签多分类` 最后一层
#
# ### 4.3 tf.keras.activations.sigmoid
# 主要用在:
# - `二分类` 问题最后一层
# - `多标签多分类` 问题最后一层
#
# <img src="./images/softmax_vs_sigmoid.png" />
# <center> softmax vs sigmoid</center>

# %% [markdown]
# ## 5. 度量指标
#
# <table style="width:100%">
#     <thead>
#         <tr>
#             <th style="text-align: left;">名称</th>
#             <th style="text-align: left;">说明</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td style="text-align: left;">accuracy</td>
#             <td style="text-align: left;">精度</td>
#         </tr>
#         <tr>
#             <td style="text-align: left;">mae</td>
#             <td style="text-align: left;">mean_absolute_error 平均绝对误差</td>
#         </tr>
#         <tr>
#             <td style="text-align: left;">mse</td>
#             <td style="text-align: left;">mean_squared_error 均方误差 </td>
#         </tr>
#     </tbody>
# </table>
#
# history样例
#
# ```json
# {
#   'acc': [0.9828, 0.98766667],
#   'loss': [0.053203841127455236, 0.04020909158239762],
#
#   'val_acc': [0.9828333, 0.98373336],
#   'val_loss': [0.05952358451932669, 0.05152393340741595],
#
#   'mean_absolute_error': [0.005526283, 0.0041116807],
#   'val_mean_absolute_error': [0.005517981, 0.0048979456],
#
#   'mean_squared_error': [0.0025828995, 0.0019050392],
#   'val_mean_squared_error': [0.0027263481, 0.002449907]
# }
# ```

# %% [markdown]
# ## 6. 补充

# %% [markdown]
# ### 6.1 MSE
#
# > MSE: Mean Squared Error
# 均方误差是指参数估计值与参数真值之差平方的期望值;
# MSE可以评价数据的变化程度，MSE的值越小，说明预测模型描述实验数据具有更好的精确度。
#
# $$MSE = \frac{1}{N}\sum_{i=1} ^N (observed_{i} - predictedt_{i} )^2 $$
#
# ### 6.2 RMSE
#
# >RMSE
# 均方根误差是均方误差的算术平方根
#
# $$RMSE = \sqrt{MSE} =\sqrt {\frac {1} {N} \sum_{i=1}^N (observed_{i} - predictedt_{i} )^2} $$
#
# ### 6.3 MAE
#
# > MAE :Mean Absolute Error
# 平均绝对误差是绝对误差的平均值
# 平均绝对误差能更好地反映预测值误差的实际情况.
#
# $$MAE = \frac {1} {N} \sum_{i=1}^N |observed_{i} - predictedt_{i}|$$
#
# ### 6.4 SD
#
# > SD :standard Deviation
# 标准差:标准差是方差的算术平方根。标准差能反映一个数据集的离散程度。平均数相同的两组组数据，标准差未必相同。
#
# $$SD = \sqrt{ \frac {1} {N} \sum_{i=1}^N (x_{i}- \overline{x})^2 }$$
#
# $$ \overline{x} 表示平均值( mean )： \overline{x} = \frac {1} {N} (x_{1} + x_{2} + ..... + x_{N})$$
