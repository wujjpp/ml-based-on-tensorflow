# %% [markdown]
# # 纯工程 - 多输入多输出
#
# 该例子只是纯工程例子，样本数据随机生成，仅仅是为了描述`可能`。

# %% [markdown]
# ## 导入包

# %%
import tensorflow as tf
import numpy as np
from matplotlib import pyplot as plt
import pandas as pd

models = tf.keras.models
layers = tf.keras.layers
losses = tf.keras.losses
optimizers = tf.keras.optimizers
activations = tf.keras.activations
Input = tf.keras.Input
utils = tf.keras.utils
TensorBoard = tf.keras.callbacks.TensorBoard

# 文本片段词典大小
text_vocabulary_size = 1000
# 问题词典大小
question_vocabulary_size = 1000
# 输入文本长度
maxlen = 50
# 样本数量
num_samples = 1000
# 收入分类数
num_income_group = 10

# %% [markdown]
# ## 3. 准备多输入层

# %%
# 处理文本输入
text_input = Input(shape=(None, ), dtype='int32', name='texts')
embedded_text = layers.Embedding(text_vocabulary_size, 64)(text_input)
encoded_text = layers.LSTM(32)(embedded_text)

# 处理问题输入
question_input = Input(shape=(None, ), dtype='int32', name='questions')
embedded_question = layers.Embedding(question_vocabulary_size, 64)(question_input)
encoded_question = layers.LSTM(64)(embedded_question)

# 连接编码后的问题和文本
concatenated = layers.concatenate([encoded_text, encoded_question], axis=-1)
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0726 06:19:44.338697 139992302946112 deprecation.py:506] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/initializers.py:119: calling RandomUniform.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# W0726 06:19:44.351014 139992302946112 deprecation.py:506] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor

# %% [markdown]
# ## 4. 准备多输出层

# %%
# 二分类问题
gender_prediction = layers.Dense(
    1,
    activation=activations.sigmoid,
    name='gender')(concatenated)


# 多分类问题
income_prediction = layers.Dense(
    num_income_group,
    activation=activations.softmax,
    name='income')(concatenated)

# 回归问题
age_prediction = layers.Dense(1, name='age')(concatenated)

# %% [markdown]
# ## 5. 构建模型

# %%
model = models.Model(
    [text_input, question_input],
    [age_prediction, income_prediction, gender_prediction]
)

model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# texts (InputLayer)              [(None, None)]       0
# __________________________________________________________________________________________________
# questions (InputLayer)          [(None, None)]       0
# __________________________________________________________________________________________________
# embedding (Embedding)           (None, None, 64)     64000       texts[0][0]
# __________________________________________________________________________________________________
# embedding_1 (Embedding)         (None, None, 64)     64000       questions[0][0]
# __________________________________________________________________________________________________
# lstm (LSTM)                     (None, 32)           12416       embedding[0][0]
# __________________________________________________________________________________________________
# lstm_1 (LSTM)                   (None, 64)           33024       embedding_1[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 96)           0           lstm[0][0]
#                                                                  lstm_1[0][0]
# __________________________________________________________________________________________________
# age (Dense)                     (None, 1)            97          concatenate[0][0]
# __________________________________________________________________________________________________
# income (Dense)                  (None, 10)           970         concatenate[0][0]
# __________________________________________________________________________________________________
# gender (Dense)                  (None, 1)            97          concatenate[0][0]
# ==================================================================================================
# Total params: 174,604
# Trainable params: 174,604
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# ## 6. 编译模型

# %%
model.compile(
    optimizer=optimizers.Adam(),  # 这个注释只是为了自动格式化
    loss={
        'age': losses.mse,
        'income': losses.categorical_crossentropy,
        'gender': losses.binary_crossentropy
    },
    # 对总loss值贡献度，详情可参考：https://tensorflow.google.cn/api_docs/python/tf/keras/Model#compile
    loss_weights={
        'age': 0.25,
        'income': 1.,
        'gender': 10.
    },
    metrics = ['accuracy', 'mae', 'mse']
)
# Out:
# W0726 06:19:45.078963 139992302946112 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/nn_impl.py:180: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where

# %% [markdown]
# ## 7. 准备模拟数据

# %%
# 准备模拟数据
# x_train(s)
texts = np.random.randint(1, text_vocabulary_size, size=(num_samples, maxlen))
questions = np.random.randint(1, question_vocabulary_size, size=(num_samples, maxlen))

# y_train(s)
# 1. 预测age是回归问题， lables.shape = (num_simples,)
age_targets = np.random.randint(16, 40, size=num_samples)

# 2. 预测income是多分类问题，有2种标签向量化方式，这边使用one-hot编码,lables.shape = (num_samples, num_income_group)
income_targets = np.random.randint(num_income_group, size=num_samples)
income_targets = utils.to_categorical(income_targets, num_income_group)

# 3. 预测gender是两分类问题, labels.shape = (num_samples, )
gender_targets = np.random.randint(2, size=num_samples)

# %% [markdown]
# ## 8. 训练模型

# %%
history = model.fit(
    {
        'texts': texts,  # 这个注释只是为了自动格式化
        'questions': questions
    },
    {
        'age': age_targets,
        'income': income_targets,
        'gender': gender_targets
    },
    epochs=100,
    batch_size=64,
    validation_split=0.2,    
    callbacks = [TensorBoard(log_dir='../results/muti-input-and-output/logs')]    
)
# Out:
# Train on 800 samples, validate on 200 samples
# Epoch 1/100
# 800/800 [==============================] - 2s 2ms/sample - loss: 209.6750 - age_loss: 800.6895 - income_loss: 2.3034 - gender_loss: 0.6935 - age_acc: 0.0000e+00 - age_mean_absolute_error: 27.4613 - age_mean_squared_error: 801.7559 - income_acc: 0.0925 - income_mean_absolute_error: 0.1800 - income_mean_squared_error: 0.0900 - gender_acc: 0.5050 - gender_mean_absolute_error: 0.5000 - gender_mean_squared_error: 0.2501 - val_loss: 207.4915 - val_age_loss: 779.6553 - val_income_loss: 2.3097 - val_gender_loss: 0.6889 - val_age_acc: 0.0000e+00 - val_age_mean_absolute_error: 27.3204 - val_age_mean_squared_error: 792.8373 - val_income_acc: 0.0800 - val_income_mean_absolute_error: 0.1801 - val_income_mean_squared_error: 0.0901 - val_gender_acc: 0.4550 - val_gender_mean_absolute_error: 0.5017 - val_gender_mean_squared_error: 0.2521
# Epoch 2/100
# 800/800 [==============================] - 1s 1ms/sample - loss: 165.8818 - age_loss: 620.7752 - income_loss: 2.3082 - gender_loss: 0.7108 - age_acc: 0.0000e+00 - age_mean_absolute_error: 23.9715 - age_mean_squared_error: 625.8765 - income_acc: 0.1275 - income_mean_absolute_error: 0.1797 - income_mean_squared_error: 0.0901 - gender_acc: 0.5000 - gender_mean_absolute_error: 0.4989 - gender_mean_squared_error: 0.2584 - val_loss: 135.1431 - val_age_loss: 548.4393 - val_income_loss: 2.3164 - val_gender_loss: 0.7378 - val_age_acc: 0.0000e+00 - val_age_mean_absolute_error: 21.3442 - val_age_mean_squared_error: 502.0509 - val_income_acc: 0.0800 - val_income_mean_absolute_error: 0.1803 - val_income_mean_squared_error: 0.0905 - val_gender_acc: 0.4550 - val_gender_mean_absolute_error: 0.5087 - val_gender_mean_squared_error: 0.2684
# Epoch 3/100
# 800/800 [==============================] - 1s 1ms/sample - loss: 105.6492 - age_loss: 380.3156 - income_loss: 2.3253 - gender_loss: 0.7042 - age_acc: 0.0000e+00 - age_mean_absolute_error: 18.3013 - age_mean_squared_error: 385.1649 - income_acc: 0.0962 - income_mean_absolute_error: 0.1801 - income_mean_squared_error: 0.0904 - gender_acc: 0.5025 - gender_mean_absolute_error: 0.5010 - gender_mean_squared_error: 0.2551 - val_loss: 81.8113 - val_age_loss: 261.7600 - val_income_loss: 2.3144 - val_gender_loss: 0.7086 - val_age_acc: 0.0000e+00 - val_age_mean_absolute_error: 15.6175 - val_age_mean_squared_error: 290.3805 - val_income_acc: 0.1200 - val_income_mean_absolute_error: 0.1798 - val_income_mean_squared_error: 0.0902 - val_gender_acc: 0.5450 - val_gender_mean_absolute_error: 0.4936 - val_gender_mean_squared_error: 0.2486
# Epoch 4/100
# 800/800 [==============================] - 1s 1ms/sample - loss: 66.8905 - age_loss: 229.9217 - income_loss: 2.3127 - gender_loss: 0.6957 - age_acc: 0.0000e+00 - age_mean_absolute_error: 13.4849 - age_mean_squared_error: 230.4830 - income_acc: 0.1213 - income_mean_absolute_error: 0.1798 - income_mean_squared_error: 0.0902 - gender_acc: 0.5000 - gender_mean_absolute_error: 0.5001 - gender_mean_squared_error: 0.2513 - val_loss: 58.7250 - val_age_loss: 202.4988 - val_income_loss: 2.3366 - val_gender_loss: 0.6988 - val_age_acc: 0.0000e+00 - val_age_mean_absolute_error: 12.2999 - val_age_mean_squared_error: 197.7330 - val_income_acc: 0.0800 - val_income_mean_absolute_error: 0.1801 - val_income_mean_squared_error: 0.0903 - val_gender_acc: 0.4550 - val_gender_mean_absolute_error: 0.5018 - val_gender_mean_squared_error: 0.2522
# Epoch 5/100
# 800/800 [==============================] - 1s 1ms/sample - loss: 50.4410 - age_loss: 164.6992 - income_loss: 2.3075 - gender_loss: 0.6935 - age_acc: 0.0000e+00 - age_mean_absolute_error: 10.8882 - age_mean_squared_error: 164.7920 - income_acc: 0.1050 - income_mean_absolute_error: 0.1799 - income_mean_squared_error: 0.0901 - gender_acc: 0.5050 - gender_mean_absolute_error: 0.4998 - gender_mean_squared_error: 0.2502 - val_loss: 46.0154 - val_age_loss: 155.2537 - val_income_loss: 2.3234 - val_gender_loss: 0.6931 - val_age_acc: 0.0000e+00 - val_age_mean_absolute_error: 10.3289 - val_age_mean_squared_error: 147.1331 - val_income_acc: 0.0800 - val_income_mean_absolute_error: 0.1801 - val_income_mean_squared_error: 0.0902 - val_gender_acc: 0.5450 - val_gender_mean_absolute_error: 0.4992 - val_gender_mean_squared_error: 0.2493
# Epoch 6/100
# 800/800 [==============================] - 1s 1ms/sample - loss: 40.9401 - age_loss: 126.3633 - income_loss: 2.3035 - gender_loss: 0.6948 - age_acc: 0.0000e+00 - age_mean_absolute_error: 9.2981 - age_mean_squared_error: 126.7534 - income_acc: 0.1275 - income_mean_absolute_error: 0.1798 - income_mean_squared_error: 0.0900 - gender_acc: 0.4888 - gender_mean_absolute_error: 0.5005 - gender_mean_squared_error: 0.2508 - val_loss: 38.9796 - val_age_loss: 107.4751 - val_income_loss: 2.2921 - val_gender_loss: 0.6927 - val_age_acc: 0.0000e+00 - val_age_mean_absolute_error: 9.2010 - val_age_mean_squared_error: 118.9450 - val_income_acc: 0.0800 - val_income_mean_absolute_error: 0.1801 - val_income_mean_squared_error: 0.0904 - val_gender_acc: 0.5450 - val_gender_mean_absolute_error: 0.4996 - val_gender_mean_squared_error: 0.2496
# Epoch 7/100
# 800/800 [==============================] - 1s 1ms/sample - loss: 35.3806 - age_loss: 104.3247 - income_loss: 2.3087 - gender_loss: 0.6940 - age_acc: 0.0000e+00 - age_mean_absolute_error: 8.4107 - age_mean_squared_error: 104.5263 - income_acc: 0.1275 - income_mean_absolute_error: 0.1797 - income_mean_squared_error: 0.0901 - gender_acc: 0.5000 - gender_mean_absolute_error: 0.5002 - gender_mean_squared_error: 0.2505 - val_loss: 34.3461 - val_age_loss: 99.1637 - val_income_loss: 2.3268 - val_gender_loss: 0.6931 - val_age_acc: 0.0000e+00 - val_age_mean_absolute_error: 8.4207 - val_age_mean_squared_error: 100.4044 - val_income_acc: 0.0800 - val_income_mean_absolute_error: 0.1801 - val_income_mean_squared_error: 0.0902 - val_gender_acc: 0.4950 - val_gender_mean_absolute_error: 0.5000 - val_gender_mean_squared_error: 0.2500
# Epoch 8/100
# 800/800 [==============================] - 1s 1ms/sample - loss: 31.5869 - age_loss: 89.5648 - income_loss: 2.3079 - gender_loss: 0.6939 - age_acc: 0.0000e+00 - age_mean_absolute_error: 7.7997 - age_mean_squared_error: 89.3578 - income_acc: 0.0938 - income_mean_absolute_error: 0.1800 - income_mean_squared_error: 0.0901 - gender_acc: 0.4863 - gender_mean_absolute_error: 0.5003 - gender_mean_squared_error: 0.2504 - val_loss: 30.8542 - val_age_loss: 86.8994 - val_income_loss: 2.3175 - val_gender_loss: 0.6931 - val_age_acc: 0.0000e+00 - val_age_mean_absolute_error: 7.7972 - val_age_mean_squared_error: 86.4626 - val_income_acc: 0.0800 - val_income_mean_absolute_error: 0.1801 - val_income_mean_squared_error: 0.0902 - val_gender_acc: 0.5450 - val_gender_mean_absolute_error: 0.4996 - val_gender_mean_squared_error: 0.2496
# Epoch 9/100
# 800/800 [==============================] - 1s 1ms/sample - loss: 28.6954 - age_loss: 78.2921 - income_loss: 2.3064 - gender_loss: 0.6943 - age_acc: 0.0000e+00 - age_mean_absolute_error: 7.3154 - age_mean_squared_error: 77.7877 - income_acc: 0.1275 - income_mean_absolute_error: 0.1798 - income_mean_squared_error: 0.0900 - gender_acc: 0.5000 - gender_mean_absolute_error: 0.5003 - gender_mean_squared_error: 0.2506 - val_loss: 28.2176 - val_age_loss: 79.4721 - val_income_loss: 2.3034 - val_gender_loss: 0.6931 - val_age_acc: 0.0000e+00 - val_age_mean_absolute_error: 7.3013 - val_age_mean_squared_error: 75.8869 - val_income_acc: 0.0800 - val_income_mean_absolute_error: 0.1800 - val_income_mean_squared_error: 0.0903 - val_gender_acc: 0.5500 - val_gender_mean_absolute_error: 0.5000 - val_gender_mean_squared_error: 0.2500
# Epoch 10/100
# 800/800 [==============================] - 1s 1ms/sample - loss: 26.5446 - age_loss: 69.2011 - income_loss: 2.3036 - gender_loss: 0.6945 - age_acc: 0.0000e+00 - age_mean_absolute_error: 6.9301 - age_mean_squared_error: 69.1783 - income_acc: 0.1175 - income_mean_absolute_error: 0.1798 - income_mean_squared_error: 0.0900 - gender_acc: 0.4938 - gender_mean_absolute_error: 0.5005 - gender_mean_squared_error: 0.2507 - val_loss: 26.2549 - val_age_loss: 65.7140 - val_income_loss: 2.3222 - val_gender_loss: 0.6928 - val_age_acc: 0.0000e+00 - val_age_mean_absolute_error: 6.9186 - val_age_mean_squared_error: 67.9880 - val_income_acc: 0.0800 - val_income_mean_absolute_error: 0.1801 - val_income_mean_squared_error: 0.0903 - val_gender_acc: 0.4550 - val_gender_mean_absolute_error: 0.5005 - val_gender_mean_squared_error: 0.2505
# Epoch 11/100
# 800/800 [==============================] - 1s 1ms/sample - loss: 24.9675 - age_loss: 62.5161 - income_loss: 2.3035 - gender_loss: 0.6939 - age_acc: 0.0000e+00 - age_mean_absolute_error: 6.6590 - age_mean_squared_error: 62.8999 - income_acc: 0.1063 - income_mean_absolute_error: 0.1798 - income_mean_squared_error: 0.0900 - gender_acc: 0.4950 - gender_mean_absolute_error: 0.5003 - gender_mean_squared_error: 0.2504 - val_loss: 24.7357 - val_age_loss: 60.4994 - val_income_loss: 2.3137 - val_gender_loss: 0.6928 - val_age_acc: 0.0000e+00 - val_age_mean_absolute_error: 6.6113 - val_age_mean_squared_error: 61.9760 - val_income_acc: 0.0800 - val_income_mean_absolute_error: 0.1801 - val_income_mean_squared_error: 0.0902 - val_gender_acc: 0.5450 - val_gender_mean_absolute_error: 0.4999 - val_gender_mean_squared_error: 0.2499
# Epoch 12/100
# 800/800 [==============================] - 1s 1ms/sample - loss: 23.8123 - age_loss: 57.9864 - income_loss: 2.3029 - gender_loss: 0.6941 - age_acc: 0.0000e+00 - age_mean_absolute_error: 6.4639 - age_mean_squared_error: 58.2739 - income_acc: 0.1275 - income_mean_absolute_error: 0.1797 - income_mean_squared_error: 0.0900 - gender_acc: 0.4850 - gender_mean_absolute_error: 0.5003 - gender_mean_squared_error: 0.2505 - val_loss: 23.6345 - val_age_loss: 55.6030 - val_income_loss: 2.3244 - val_gender_loss: 0.6930 - val_age_acc: 0.0000e+00 - val_age_mean_absolute_error: 6.3820 - val_age_mean_squared_error: 57.5850 - val_income_acc: 0.0800 - val_income_mean_absolute_error: 0.1801 - val_income_mean_squared_error: 0.0903 - val_gender_acc: 0.5450 - val_gender_mean_absolute_error: 0.4995 - val_gender_mean_squared_error: 0.2496
# Epoch 13/100
# 800/800 [==============================] - 1s 1ms/sample - loss: 22.9780 - age_loss: 54.8660 - income_loss: 2.3032 - gender_loss: 0.6952 - age_acc: 0.0000e+00 - age_mean_absolute_error: 6.2953 - age_mean_squared_error: 54.8812 - income_acc: 0.1275 - income_mean_absolute_error: 0.1797 - income_mean_squared_error: 0.0900 - gender_acc: 0.5000 - gender_mean_absolute_error: 0.5003 - gender_mean_squared_error: 0.2512 - val_loss: 22.8536 - val_age_loss: 51.4805 - val_income_loss: 2.3101 - val_gender_loss: 0.6903 - val_age_acc: 0.0000e+00 - val_age_mean_absolute_error: 6.2044 - val_age_mean_squared_error: 54.4865 - val_income_acc: 0.0800 - val_income_mean_absolute_error: 0.1802 - val_income_mean_squared_error: 0.0904 - val_gender_acc: 0.5450 - val_gender_mean_absolute_error: 0.4988 - val_gender_mean_squared_error: 0.2490
# Epoch 14/100
# 800/800 [==============================] - 1s 1ms/sample - loss: 22.3601 - age_loss: 52.7190 - income_loss: 2.3009 - gender_loss: 0.6925 - age_acc: 0.0000e+00 - age_mean_absolute_error: 6.1858 - age_mean_squared_error: 52.5138 - income_acc: 0.1275 - income_mean_absolute_error: 0.1798 - income_mean_squared_error: 0.0900 - gender_acc: 0.5000 - gender_mean_absolute_error: 0.4998 - gender_mean_squared_error: 0.2499 - val_loss: 22.3572 - val_age_loss: 51.5057 - val_income_loss: 2.3140 - val_gender_loss: 0.7039 - val_age_acc: 0.0000e+00 - val_age_mean_absolute_error: 6.0665 - val_age_mean_squared_error: 52.2286 - val_income_acc: 0.0800 - val_income_mean_absolute_error: 0.1800 - val_income_mean_squared_error: 0.0901 - val_gender_acc: 0.4550 - val_gender_mean_absolute_error: 0.5023 - val_gender_mean_squared_error: 0.2530
# Epoch 15/100
# 800/800 [==============================] - 1s 1ms/sample - loss: 21.9816 - age_loss: 50.9017 - income_loss: 2.3014 - gender_loss: 0.6954 - age_acc: 0.0000e+00 - age_mean_absolute_error: 6.1102 - age_mean_squared_error: 50.8978 - income_acc: 0.1075 - income_mean_absolute_error: 0.1799 - income_mean_squared_error: 0.0900 - gender_acc: 0.4975 - gender_mean_absolute_error: 0.5004 - gender_mean_squared_error: 0.2512 - val_loss: 21.8814 - val_age_loss: 49.6221 - val_income_loss: 2.3090 - val_gender_loss: 0.6927 - val_age_acc: 0.0000e+00 - val_age_mean_absolute_error: 5.9499 - val_age_mean_squared_error: 50.5718 - val_income_acc: 0.0800 - val_income_mean_absolute_error: 0.1801 - val_income_mean_squared_error: 0.0902 - val_gender_acc: 0.5450 - val_gender_mean_absolute_error: 0.4997 - val_gender_mean_squared_error: 0.2497
# Epoch 16/100
# 800/800 [==============================] - 1s 1ms/sample - loss: 21.6898 - age_loss: 49.8889 - income_loss: 2.3066 - gender_loss: 0.6941 - age_acc: 0.0000e+00 - age_mean_absolute_error: 6.0541 - age_mean_squared_error: 49.7781 - income_acc: 0.1275 - income_mean_absolute_error: 0.1797 - income_mean_squared_error: 0.0900 - gender_acc: 0.4975 - gender_mean_absolute_error: 0.5003 - gender_mean_squared_error: 0.2505 - val_loss: 21.6103 - val_age_loss: 51.9034 - val_income_loss: 2.3173 - val_gender_loss: 0.6939 - val_age_acc: 0.0000e+00 - val_age_mean_absolute_error: 5.8869 - val_age_mean_squared_error: 49.3921 - val_income_acc: 0.0800 - val_income_mean_absolute_error: 0.1802 - val_income_mean_squared_error: 0.0905 - val_gender_acc: 0.4550 - val_gender_mean_absolute_error: 0.5003 - val_gender_mean_squared_error: 0.2503
# Epoch 17/100
# 800/800 [==============================] - 1s 1ms/sample - loss: 21.4949 - age_loss: 49.3253 - income_loss: 2.3014 - gender_loss: 0.6937 - age_acc: 0.0000e+00 - age_mean_absolute_error: 6.0201 - age_mean_squared_error: 49.0235 - income_acc: 0.1100 - income_mean_absolute_error: 0.1799 - income_mean_squared_error: 0.0900 - gender_acc: 0.4750 - gender_mean_absolute_error: 0.5002 - gender_mean_squared_error: 0.2503 - val_loss: 21.3812 - val_age_loss: 49.3772 - val_income_loss: 2.3005 - val_gender_loss: 0.6945 - val_age_acc: 0.0000e+00 - val_age_mean_absolute_error: 5.8340 - val_age_mean_squared_error: 48.5551 - val_income_acc: 0.0800 - val_income_mean_absolute_error: 0.1800 - val_income_mean_squared_error: 0.0901 - val_gender_acc: 0.4550 - val_gender_mean_absolute_error: 0.5002 - val_gender_mean_squared_error: 0.2502
# Epoch 18/100
# 800/800 [==============================] - 1s 1ms/sample - loss: 21.3684 - age_loss: 48.2952 - income_loss: 2.3018 - gender_loss: 0.6942 - age_acc: 0.0000e+00 - age_mean_absolute_error: 5.9947 - age_mean_squared_error: 48.4915 - income_acc: 0.1275 - income_mean_absolute_error: 0.1798 - income_mean_squared_error: 0.0900 - gender_acc: 0.5000 - gender_mean_absolute_error: 0.5004 - gender_mean_squared_error: 0.2505 - val_loss: 21.2374 - val_age_loss: 47.7362 - val_income_loss: 2.3124 - val_gender_loss: 0.6930 - val_age_acc: 0.0000e+00 - val_age_mean_absolute_error: 5.7926 - val_age_mean_squared_error: 47.9973 - val_income_acc: 0.0800 - val_income_mean_absolute_error: 0.1801 - val_income_mean_squared_error: 0.0903 - val_gender_acc: 0.5450 - val_gender_mean_absolute_error: 0.4995 - val_gender_mean_squared_error: 0.2495
# Epoch 19/100
# 800/800 [==============================] - 1s 1ms/sample - loss: 21.2787 - age_loss: 48.7775 - income_loss: 2.3020 - gender_loss: 0.6936 - age_acc: 0.0000e+00 - age_mean_absolute_error: 5.9737 - age_mean_squared_error: 48.1679 - income_acc: 0.1275 - income_mean_absolute_error: 0.1798 - income_mean_squared_error: 0.0900 - gender_acc: 0.5000 - gender_mean_absolute_error: 0.5001 - gender_mean_squared_error: 0.2502 - val_loss: 21.1230 - val_age_loss: 47.1362 - val_income_loss: 2.3185 - val_gender_loss: 0.6900 - val_age_acc: 0.0000e+00 - val_age_mean_absolute_error: 5.7578 - val_age_mean_squared_error: 47.5943 - val_income_acc: 0.0800 - val_income_mean_absolute_error: 0.1801 - val_income_mean_squared_error: 0.0903 - val_gender_acc: 0.5450 - val_gender_mean_absolute_error: 0.4987 - val_gender_mean_squared_error: 0.2489
# Epoch 20/100
# 800/800 [==============================] - 1s 1ms/sample - loss: 21.2333 - age_loss: 48.0042 - income_loss: 2.3037 - gender_loss: 0.6943 - age_acc: 0.0000e+00 - age_mean_absolute_error: 5.9608 - age_mean_squared_error: 47.9622 - income_acc: 0.1275 - income_mean_absolute_error: 0.1798 - income_mean_squared_error: 0.0900 - gender_acc: 0.4800 - gender_mean_absolute_error: 0.5004 - gender_mean_squared_error: 0.2505 - val_loss: 21.0980 - val_age_loss: 49.3458 - val_income_loss: 2.3201 - val_gender_loss: 0.6937 - val_age_acc: 0.0000e+00 - val_age_mean_absolute_error: 5.7470 - val_age_mean_squared_error: 47.3000 - val_income_acc: 0.0800 - val_income_mean_absolute_error: 0.1802 - val_income_mean_squared_error: 0.0903 - val_gender_acc: 0.4550 - val_gender_mean_absolute_error: 0.5010 - val_gender_mean_squared_error: 0.2511
# Epoch 21/100
# 800/800 [==============================] - 1s 1ms/sample - loss: 21.1905 - age_loss: 48.1943 - income_loss: 2.3020 - gender_loss: 0.6932 - age_acc: 0.0000e+00 - age_mean_absolute_error: 5.9593 - age_mean_squared_error: 47.8245 - income_acc: 0.1275 - income_mean_absolute_error: 0.1798 - income_mean_squared_error: 0.0900 - gender_acc: 0.5000 - gender_mean_absolute_error: 0.5000 - gender_mean_squared_error: 0.2500 - val_loss: 21.0100 - val_age_loss: 41.4119 - val_income_loss: 2.3038 - val_gender_loss: 0.6941 - val_age_acc: 0.0000e+00 - val_age_mean_absolute_error: 5.7413 - val_age_mean_squared_error: 47.1342 - val_income_acc: 0.0800 - val_income_mean_absolute_error: 0.1800 - val_income_mean_squared_error: 0.0902 - val_gender_acc: 0.5450 - val_gender_mean_absolute_error: 0.4991 - val_gender_mean_squared_error: 0.2492
# Epoch 22/100
# 800/800 [==============================] - 1s 1ms/sample - loss: 21.1791 - age_loss: 47.1533 - income_loss: 2.3052 - gender_loss: 0.6937 - age_acc: 0.0000e+00 - age_mean_absolute_error: 5.9598 - age_mean_squared_error: 47.7519 - income_acc: 0.1275 - income_mean_absolute_error: 0.1799 - income_mean_squared_error: 0.0900 - gender_acc: 0.5000 - gender_mean_absolute_error: 0.5002 - gender_mean_squared_error: 0.2503 - val_loss: 20.9817 - val_age_loss: 49.2519 - val_income_loss: 2.3271 - val_gender_loss: 0.6924 - val_age_acc: 0.0000e+00 - val_age_mean_absolute_error: 5.7356 - val_age_mean_squared_error: 46.9874 - val_income_acc: 0.0800 - val_income_mean_absolute_error: 0.1801 - val_income_mean_squared_error: 0.0902 - val_gender_acc: 0.5450 - val_gender_mean_absolute_error: 0.4995 - val_gender_mean_squared_error: 0.2495
# Epoch 23/100
# 800/800 [==============================] - 1s 1ms/sample - loss: 21.1648 - age_loss: 47.7243 - income_loss: 2.3028 - gender_loss: 0.6935 - age_acc: 0.0000e+00 - age_mean_absolute_error: 5.9600 - age_mean_squared_error: 47.7133 - income_acc: 0.1138 - income_mean_absolute_error: 0.1798 - income_mean_squared_error: 0.0900 - gender_acc: 0.4800 - gender_mean_absolute_error: 0.5002 - gender_mean_squared_error: 0.2502 - val_loss: 20.9660 - val_age_loss: 50.9554 - val_income_loss: 2.3178 - val_gender_loss: 0.6933 - val_age_acc: 0.0000e+00 - val_age_mean_absolute_error: 5.7298 - val_age_mean_squared_error: 46.8554 - val_income_acc: 0.0800 - val_income_mean_absolute_error: 0.1801 - val_income_mean_squared_error: 0.0902 - val_gender_acc: 0.4550 - val_gender_mean_absolute_error: 0.5003 - val_gender_mean_squared_error: 0.2504
# Epoch 24/100
# 800/800 [==============================] - 1s 1ms/sample - loss: 21.1848 - age_loss: 47.6900 - income_loss: 2.3072 - gender_loss: 0.6964 - age_acc: 0.0000e+00 - age_mean_absolute_error: 5.9589 - age_mean_squared_error: 47.6621 - income_acc: 0.1275 - income_mean_absolute_error: 0.1799 - income_mean_squared_error: 0.0901 - gender_acc: 0.5000 - gender_mean_absolute_error: 0.5006 - gender_mean_squared_error: 0.2516 - val_loss: 20.9554 - val_age_loss: 46.7793 - val_income_loss: 2.3268 - val_gender_loss: 0.6938 - val_age_acc: 0.0000e+00 - val_age_mean_absolute_error: 5.7272 - val_age_mean_squared_error: 46.8023 - val_income_acc: 0.0800 - val_income_mean_absolute_error: 0.1801 - val_income_mean_squared_error: 0.0903 - val_gender_acc: 0.4550 - val_gender_mean_absolute_error: 0.5004 - val_gender_mean_squared_error: 0.2504
# Epoch 25/100
# 800/800 [==============================] - 1s 1ms/sample - loss: 21.1531 - age_loss: 47.4783 - income_loss: 2.3032 - gender_loss: 0.6934 - age_acc: 0.0000e+00 - age_mean_absolute_error: 5.9593 - age_mean_squared_error: 47.6496 - income_acc: 0.1275 - income_mean_absolute_error: 0.1799 - income_mean_squared_error: 0.0900 - gender_acc: 0.5075 - gender_mean_absolute_error: 0.4999 - gender_mean_squared_error: 0.2503 - val_loss: 20.9032 - val_age_loss: 46.4787 - val_income_loss: 2.3191 - val_gender_loss: 0.6869 - val_age_acc: 0.0000e+00 - val_age_mean_absolute_error: 5.7236 - val_age_mean_squared_error: 46.7344 - val_income_acc: 0.0800 - val_income_mean_absolute_error: 0.1801 - val_income_mean_squared_error: 0.0903 - val_gender_acc: 0.5450 - val_gender_mean_absolute_error: 0.4982 - val_gender_mean_squared_error: 0.2486
# Epoch 26/100
# 800/800 [==============================] - 1s 1ms/sample - loss: 21.1508 - age_loss: 47.7110 - income_loss: 2.3040 - gender_loss: 0.6937 - age_acc: 0.0000e+00 - age_mean_absolute_error: 5.9591 - age_mean_squared_error: 47.6461 - income_acc: 0.1275 - income_mean_absolute_error: 0.1798 - income_mean_squared_error: 0.0900 - gender_acc: 0.4975 - gender_mean_absolute_error: 0.5000 - gender_mean_squared_error: 0.2503 - val_loss: 20.9290 - val_age_loss: 47.8756 - val_income_loss: 2.2995 - val_gender_loss: 0.6937 - val_age_acc: 0.0000e+00 - val_age_mean_absolute_error: 5.7211 - val_age_mean_squared_error: 46.6925 - val_income_acc: 0.0800 - val_income_mean_absolute_error: 0.1801 - val_income_mean_squared_error: 0.0903 - val_gender_acc: 0.4550 - val_gender_mean_absolute_error: 0.5003 - val_gender_mean_squared_error: 0.2504
# Epoch 27/100
# 800/800 [==============================] - 1s 1ms/sample - loss: 21.1562 - age_loss: 47.6809 - income_loss: 2.3057 - gender_loss: 0.6944 - age_acc: 0.0000e+00 - age_mean_absolute_error: 5.9589 - age_mean_squared_error: 47.6421 - income_acc: 0.1163 - income_mean_absolute_error: 0.1799 - income_mean_squared_error: 0.0900 - gender_acc: 0.5000 - gender_mean_absolute_error: 0.5003 - gender_mean_squared_error: 0.2505 - val_loss: 20.9243 - val_age_loss: 48.1436 - val_income_loss: 2.3018 - val_gender_loss: 0.6912 - val_age_acc: 0.0000e+00 - val_age_mean_absolute_error: 5.7192 - val_age_mean_squared_error: 46.6616 - val_income_acc: 0.0800 - val_income_mean_absolute_error: 0.1801 - val_income_mean_squared_error: 0.0902 - val_gender_acc: 0.4550 - val_gender_mean_absolute_error: 0.5006 - val_gender_mean_squared_error: 0.2507
# Epoch 28/100
# 800/800 [==============================] - 1s 1ms/sample - loss: 21.1524 - age_loss: 47.2102 - income_loss: 2.3011 - gender_loss: 0.6944 - age_acc: 0.0000e+00 - age_mean_absolute_error: 5.9584 - age_mean_squared_error: 47.6342 - income_acc: 0.1275 - income_mean_absolute_error: 0.1798 - income_mean_squared_error: 0.0900 - gender_acc: 0.4975 - gender_mean_absolute_error: 0.5003 - gender_mean_squared_error: 0.2506 - val_loss: 20.8937 - val_age_loss: 50.4474 - val_income_loss: 2.3197 - val_gender_loss: 0.6899 - val_age_acc: 0.0000e+00 - val_age_mean_absolute_error: 5.7193 - val_age_mean_squared_error: 46.6631 - val_income_acc: 0.0800 - val_income_mean_absolute_error: 0.1801 - val_income_mean_squared_error: 0.0902 - val_gender_acc: 0.5450 - val_gender_mean_absolute_error: 0.4991 - val_gender_mean_squared_error: 0.2492
# Epoch 29/100
# 800/800 [==============================] - 1s 1ms/sample - loss: 21.1580 - age_loss: 48.0520 - income_loss: 2.3033 - gender_loss: 0.6947 - age_acc: 0.0000e+00 - age_mean_absolute_error: 5.9583 - age_mean_squared_error: 47.6329 - income_acc: 0.1275 - income_mean_absolute_error: 0.1799 - income_mean_squared_error: 0.0900 - gender_acc: 0.4925 - gender_mean_absolute_error: 0.5004 - gender_mean_squared_error: 0.2508 - val_loss: 20.9508 - val_age_loss: 48.0131 - val_income_loss: 2.3012 - val_gender_loss: 0.6983 - val_age_acc: 0.0000e+00 - val_age_mean_absolute_error: 5.7187 - val_age_mean_squared_error: 46.6542 - val_income_acc: 0.0800 - val_income_mean_absolute_error: 0.1801 - val_income_mean_squared_error: 0.0903 - val_gender_acc: 0.4550 - val_gender_mean_absolute_error: 0.5016 - val_gender_mean_squared_error: 0.2520
# Epoch 30/100
# 800/800 [==============================] - 1s 1ms/sample - loss: 21.1585 - age_loss: 47.5285 - income_loss: 2.3046 - gender_loss: 0.6949 - age_acc: 0.0000e+00 - age_mean_absolute_error: 5.9582 - age_mean_squared_error: 47.6323 - income_acc: 0.1275 - income_mean_absolute_error: 0.1797 - income_mean_squared_error: 0.0900 - gender_acc: 0.5025 - gender_mean_absolute_error: 0.5003 - gender_mean_squared_error: 0.2507 - val_loss: 20.8894 - val_age_loss: 50.7552 - val_income_loss: 2.3254 - val_gender_loss: 0.6865 - val_age_acc: 0.0000e+00 - val_age_mean_absolute_error: 5.7180 - val_age_mean_squared_error: 46.6435 - val_income_acc: 0.0800 - val_income_mean_absolute_error: 0.1802 - val_income_mean_squared_error: 0.0905 - val_gender_acc: 0.5450 - val_gender_mean_absolute_error: 0.4981 - val_gender_mean_squared_error: 0.2486
# Epoch 31/100
# 800/800 [==============================] - 1s 1ms/sample - loss: 21.1480 - age_loss: 47.6576 - income_loss: 2.3054 - gender_loss: 0.6933 - age_acc: 0.0000e+00 - age_mean_absolute_error: 5.9583 - age_mean_squared_error: 47.6360 - income_acc: 0.1275 - income_mean_absolute_error: 0.1797 - income_mean_squared_error: 0.0900 - gender_acc: 0.5025 - gender_mean_absolute_error: 0.5000 - gender_mean_squared_error: 0.2501 - val_loss: 20.9233 - val_age_loss: 52.3676 - val_income_loss: 2.3161 - val_gender_loss: 0.6976 - val_age_acc: 0.0000e+00 - val_age_mean_absolute_error: 5.7171 - val_age_mean_squared_error: 46.6307 - val_income_acc: 0.0800 - val_income_mean_absolute_error: 0.1801 - val_income_mean_squared_error: 0.0902 - val_gender_acc: 0.4550 - val_gender_mean_absolute_error: 0.5010 - val_gender_mean_squared_error: 0.2512
# Epoch 32/100
# 800/800 [==============================] - 1s 1ms/sample - loss: 21.1650 - age_loss: 47.5750 - income_loss: 2.3016 - gender_loss: 0.6954 - age_acc: 0.0000e+00 - age_mean_absolute_error: 5.9582 - age_mean_squared_error: 47.6327 - income_acc: 0.1275 - income_mean_absolute_error: 0.1799 - income_mean_squared_error: 0.0900 - gender_acc: 0.5000 - gender_mean_absolute_error: 0.5005 - gender_mean_squared_error: 0.2512 - val_loss: 20.8906 - val_age_loss: 44.9970 - val_income_loss: 2.3130 - val_gender_loss: 0.6903 - val_age_acc: 0.0000e+00 - val_age_mean_absolute_error: 5.7175 - val_age_mean_squared_error: 46.6369 - val_income_acc: 0.0800 - val_income_mean_absolute_error: 0.1801 - val_income_mean_squared_error: 0.0902 - val_gender_acc: 0.5450 - val_gender_mean_absolute_error: 0.4992 - val_gender_mean_squared_error: 0.2493
# Epoch 33/100
# 800/800 [==============================] - 1s 1ms/sample - loss: 21.1610 - age_loss: 47.8735 - income_loss: 2.3028 - gender_loss: 0.6948 - age_acc: 0.0000e+00 - age_mean_absolute_error: 5.9585 - age_mean_squared_error: 47.6345 - income_acc: 0.1275 - income_mean_absolute_error: 0.1798 - income_mean_squared_error: 0.0900 - gender_acc: 0.5000 - gender_mean_absolute_error: 0.5003 - gender_mean_squared_error: 0.2509 - val_loss: 20.8914 - val_age_loss: 46.9257 - val_income_loss: 2.3190 - val_gender_loss: 0.6917 - val_age_acc: 0.0000e+00 - val_age_mean_absolute_error: 5.7179 - val_age_mean_squared_error: 46.6424 - val_income_acc: 0.0800 - val_income_mean_absolute_error: 0.1801 - val_income_mean_squared_error: 0.0904 - val_gender_acc: 0.5450 - val_gender_mean_absolute_error: 0.4989 - val_gender_mean_squared_error: 0.2490
# Epoch 34/100
# 800/800 [==============================] - 1s 1ms/sample - loss: 21.1465 - age_loss: 47.4788 - income_loss: 2.3012 - gender_loss: 0.6944 - age_acc: 0.0000e+00 - age_mean_absolute_error: 5.9580 - age_mean_squared_error: 47.6324 - income_acc: 0.1275 - income_mean_absolute_error: 0.1797 - income_mean_squared_error: 0.0900 - gender_acc: 0.4975 - gender_mean_absolute_error: 0.5001 - gender_mean_squared_error: 0.2503 - val_loss: 20.9455 - val_age_loss: 49.4325 - val_income_loss: 2.3132 - val_gender_loss: 0.6965 - val_age_acc: 0.0000e+00 - val_age_mean_absolute_error: 5.7166 - val_age_mean_squared_error: 46.6247 - val_income_acc: 0.0800 - val_income_mean_absolute_error: 0.1801 - val_income_mean_squared_error: 0.0903 - val_gender_acc: 0.4550 - val_gender_mean_absolute_error: 0.5017 - val_gender_mean_squared_error: 0.2521
# Epoch 35/100
# 800/800 [==============================] - 1s 1ms/sample - loss: 21.1602 - age_loss: 47.4685 - income_loss: 2.3056 - gender_loss: 0.6947 - age_acc: 0.0000e+00 - age_mean_absolute_error: 5.9586 - age_mean_squared_error: 47.6386 - income_acc: 0.1275 - income_mean_absolute_error: 0.1799 - income_mean_squared_error: 0.0901 - gender_acc: 0.5000 - gender_mean_absolute_error: 0.5003 - gender_mean_squared_error: 0.2506 - val_loss: 20.8759 - val_age_loss: 47.7321 - val_income_loss: 2.3234 - val_gender_loss: 0.6932 - val_age_acc: 0.0000e+00 - val_age_mean_absolute_error: 5.7164 - val_age_mean_squared_error: 46.6209 - val_income_acc: 0.0800 - val_income_mean_absolute_error: 0.1801 - val_income_mean_squared_error: 0.0902 - val_gender_acc: 0.5450 - val_gender_mean_absolute_error: 0.4985 - val_gender_mean_squared_error: 0.2488
# Epoch 36/100
# 800/800 [==============================] - 1s 1ms/sample - loss: 21.1488 - age_loss: 47.7000 - income_loss: 2.3061 - gender_loss: 0.6934 - age_acc: 0.0000e+00 - age_mean_absolute_error: 5.9582 - age_mean_squared_error: 47.6388 - income_acc: 0.1275 - income_mean_absolute_error: 0.1797 - income_mean_squared_error: 0.0900 - gender_acc: 0.4950 - gender_mean_absolute_error: 0.5001 - gender_mean_squared_error: 0.2502 - val_loss: 20.9435 - val_age_loss: 51.3676 - val_income_loss: 2.3263 - val_gender_loss: 0.6963 - val_age_acc: 0.0000e+00 - val_age_mean_absolute_error: 5.7152 - val_age_mean_squared_error: 46.6051 - val_income_acc: 0.0800 - val_income_mean_absolute_error: 0.1801 - val_income_mean_squared_error: 0.0904 - val_gender_acc: 0.4550 - val_gender_mean_absolute_error: 0.5016 - val_gender_mean_squared_error: 0.2519
# Epoch 37/100
# 800/800 [==============================] - 1s 1ms/sample - loss: 21.1514 - age_loss: 47.5507 - income_loss: 2.3025 - gender_loss: 0.6938 - age_acc: 0.0000e+00 - age_mean_absolute_error: 5.9591 - age_mean_squared_error: 47.6444 - income_acc: 0.1200 - income_mean_absolute_error: 0.1798 - income_mean_squared_error: 0.0900 - gender_acc: 0.5000 - gender_mean_absolute_error: 0.5002 - gender_mean_squared_error: 0.2503 - val_loss: 20.9002 - val_age_loss: 47.5756 - val_income_loss: 2.3206 - val_gender_loss: 0.6931 - val_age_acc: 0.0000e+00 - val_age_mean_absolute_error: 5.7167 - val_age_mean_squared_error: 46.6259 - val_income_acc: 0.0800 - val_income_mean_absolute_error: 0.1801 - val_income_mean_squared_error: 0.0902 - val_gender_acc: 0.5450 - val_gender_mean_absolute_error: 0.4999 - val_gender_mean_squared_error: 0.2499
# Epoch 38/100
# 800/800 [==============================] - 1s 1ms/sample - loss: 21.1471 - age_loss: 47.8854 - income_loss: 2.3021 - gender_loss: 0.6937 - age_acc: 0.0000e+00 - age_mean_absolute_error: 5.9583 - age_mean_squared_error: 47.6356 - income_acc: 0.1275 - income_mean_absolute_error: 0.1799 - income_mean_squared_error: 0.0900 - gender_acc: 0.4800 - gender_mean_absolute_error: 0.5003 - gender_mean_squared_error: 0.2503 - val_loss: 20.8884 - val_age_loss: 47.2328 - val_income_loss: 2.3101 - val_gender_loss: 0.6925 - val_age_acc: 0.0000e+00 - val_age_mean_absolute_error: 5.7158 - val_age_mean_squared_error: 46.6129 - val_income_acc: 0.0800 - val_income_mean_absolute_error: 0.1801 - val_income_mean_squared_error: 0.0902 - val_gender_acc: 0.5450 - val_gender_mean_absolute_error: 0.4995 - val_gender_mean_squared_error: 0.2495
# Epoch 39/100
# 800/800 [==============================] - 1s 1ms/sample - loss: 21.1471 - age_loss: 47.6216 - income_loss: 2.3034 - gender_loss: 0.6938 - age_acc: 0.0000e+00 - age_mean_absolute_error: 5.9581 - age_mean_squared_error: 47.6327 - income_acc: 0.1275 - income_mean_absolute_error: 0.1798 - income_mean_squared_error: 0.0900 - gender_acc: 0.4975 - gender_mean_absolute_error: 0.5002 - gender_mean_squared_error: 0.2502 - val_loss: 20.9271 - val_age_loss: 42.6808 - val_income_loss: 2.3242 - val_gender_loss: 0.6926 - val_age_acc: 0.0000e+00 - val_age_mean_absolute_error: 5.7168 - val_age_mean_squared_error: 46.6271 - val_income_acc: 0.0800 - val_income_mean_absolute_error: 0.1802 - val_income_mean_squared_error: 0.0904 - val_gender_acc: 0.4550 - val_gender_mean_absolute_error: 0.5007 - val_gender_mean_squared_error: 0.2508
# Epoch 40/100
# 800/800 [==============================] - 1s 1ms/sample - loss: 21.1551 - age_loss: 47.2704 - income_loss: 2.3076 - gender_loss: 0.6944 - age_acc: 0.0000e+00 - age_mean_absolute_error: 5.9584 - age_mean_squared_error: 47.6331 - income_acc: 0.1275 - income_mean_absolute_error: 0.1798 - income_mean_squared_error: 0.0901 - gender_acc: 0.5100 - gender_mean_absolute_error: 0.5002 - gender_mean_squared_error: 0.2504 - val_loss: 20.8722 - val_age_loss: 50.2713 - val_income_loss: 2.3111 - val_gender_loss: 0.6934 - val_age_acc: 0.0000e+00 - val_age_mean_absolute_error: 5.7165 - val_age_mean_squared_error: 46.6227 - val_income_acc: 0.0800 - val_income_mean_absolute_error: 0.1801 - val_income_mean_squared_error: 0.0902 - val_gender_acc: 0.5450 - val_gender_mean_absolute_error: 0.4981 - val_gender_mean_squared_error: 0.2486
# Epoch 41/100
# 800/800 [==============================] - 1s 1ms/sample - loss: 21.1534 - age_loss: 47.6133 - income_loss: 2.3073 - gender_loss: 0.6934 - age_acc: 0.0000e+00 - age_mean_absolute_error: 5.9583 - age_mean_squared_error: 47.6354 - income_acc: 0.1125 - income_mean_absolute_error: 0.1799 - income_mean_squared_error: 0.0901 - gender_acc: 0.5000 - gender_mean_absolute_error: 0.5001 - gender_mean_squared_error: 0.2503 - val_loss: 20.9294 - val_age_loss: 44.8800 - val_income_loss: 2.2993 - val_gender_loss: 0.6992 - val_age_acc: 0.0000e+00 - val_age_mean_absolute_error: 5.7164 - val_age_mean_squared_error: 46.6216 - val_income_acc: 0.1050 - val_income_mean_absolute_error: 0.1800 - val_income_mean_squared_error: 0.0902 - val_gender_acc: 0.4550 - val_gender_mean_absolute_error: 0.5014 - val_gender_mean_squared_error: 0.2516
# Epoch 42/100
# 800/800 [==============================] - 1s 1ms/sample - loss: 21.1716 - age_loss: 47.4478 - income_loss: 2.3062 - gender_loss: 0.6957 - age_acc: 0.0000e+00 - age_mean_absolute_error: 5.9584 - age_mean_squared_error: 47.6369 - income_acc: 0.1225 - income_mean_absolute_error: 0.1799 - income_mean_squared_error: 0.0900 - gender_acc: 0.4975 - gender_mean_absolute_error: 0.5005 - gender_mean_squared_error: 0.2513 - val_loss: 20.9026 - val_age_loss: 45.9832 - val_income_loss: 2.2942 - val_gender_loss: 0.6906 - val_age_acc: 0.0000e+00 - val_age_mean_absolute_error: 5.7176 - val_age_mean_squared_error: 46.6387 - val_income_acc: 0.0800 - val_income_mean_absolute_error: 0.1802 - val_income_mean_squared_error: 0.0904 - val_gender_acc: 0.5450 - val_gender_mean_absolute_error: 0.4993 - val_gender_mean_squared_error: 0.2494
# Epoch 43/100
# 800/800 [==============================] - 1s 1ms/sample - loss: 21.1725 - age_loss: 48.2580 - income_loss: 2.3031 - gender_loss: 0.6958 - age_acc: 0.0000e+00 - age_mean_absolute_error: 5.9592 - age_mean_squared_error: 47.6453 - income_acc: 0.1275 - income_mean_absolute_error: 0.1798 - income_mean_squared_error: 0.0900 - gender_acc: 0.4850 - gender_mean_absolute_error: 0.5010 - gender_mean_squared_error: 0.2514 - val_loss: 20.9168 - val_age_loss: 43.8344 - val_income_loss: 2.3107 - val_gender_loss: 0.6945 - val_age_acc: 0.0000e+00 - val_age_mean_absolute_error: 5.7170 - val_age_mean_squared_error: 46.6298 - val_income_acc: 0.0800 - val_income_mean_absolute_error: 0.1800 - val_income_mean_squared_error: 0.0902 - val_gender_acc: 0.4550 - val_gender_mean_absolute_error: 0.5008 - val_gender_mean_squared_error: 0.2509
# Epoch 44/100
# 800/800 [==============================] - 1s 1ms/sample - loss: 21.1454 - age_loss: 47.3650 - income_loss: 2.3008 - gender_loss: 0.6935 - age_acc: 0.0000e+00 - age_mean_absolute_error: 5.9587 - age_mean_squared_error: 47.6402 - income_acc: 0.1275 - income_mean_absolute_error: 0.1798 - income_mean_squared_error: 0.0900 - gender_acc: 0.4800 - gender_mean_absolute_error: 0.5001 - gender_mean_squared_error: 0.2502 - val_loss: 20.9116 - val_age_loss: 39.5992 - val_income_loss: 2.3201 - val_gender_loss: 0.6933 - val_age_acc: 0.0000e+00 - val_age_mean_absolute_error: 5.7189 - val_age_mean_squared_error: 46.6579 - val_income_acc: 0.0800 - val_income_mean_absolute_error: 0.1801 - val_income_mean_squared_error: 0.0902 - val_gender_acc: 0.4550 - val_gender_mean_absolute_error: 0.5001 - val_gender_mean_squared_error: 0.2501
# Epoch 45/100
# 800/800 [==============================] - 1s 1ms/sample - loss: 21.1470 - age_loss: 47.7036 - income_loss: 2.2995 - gender_loss: 0.6939 - age_acc: 0.0000e+00 - age_mean_absolute_error: 5.9585 - age_mean_squared_error: 47.6356 - income_acc: 0.1213 - income_mean_absolute_error: 0.1798 - income_mean_squared_error: 0.0899 - gender_acc: 0.4600 - gender_mean_absolute_error: 0.5003 - gender_mean_squared_error: 0.2503 - val_loss: 20.9070 - val_age_loss: 48.5026 - val_income_loss: 2.3118 - val_gender_loss: 0.6926 - val_age_acc: 0.0000e+00 - val_age_mean_absolute_error: 5.7190 - val_age_mean_squared_error: 46.6594 - val_income_acc: 0.1050 - val_income_mean_absolute_error: 0.1801 - val_income_mean_squared_error: 0.0903 - val_gender_acc: 0.5450 - val_gender_mean_absolute_error: 0.4997 - val_gender_mean_squared_error: 0.2497
# Epoch 46/100
# 800/800 [==============================] - 1s 1ms/sample - loss: 21.1524 - age_loss: 47.3919 - income_loss: 2.3012 - gender_loss: 0.6941 - age_acc: 0.0000e+00 - age_mean_absolute_error: 5.9589 - age_mean_squared_error: 47.6402 - income_acc: 0.1287 - income_mean_absolute_error: 0.1797 - income_mean_squared_error: 0.0900 - gender_acc: 0.4450 - gender_mean_absolute_error: 0.5004 - gender_mean_squared_error: 0.2505 - val_loss: 20.9207 - val_age_loss: 51.6874 - val_income_loss: 2.3338 - val_gender_loss: 0.6935 - val_age_acc: 0.0000e+00 - val_age_mean_absolute_error: 5.7200 - val_age_mean_squared_error: 46.6740 - val_income_acc: 0.0800 - val_income_mean_absolute_error: 0.1801 - val_income_mean_squared_error: 0.0903 - val_gender_acc: 0.4550 - val_gender_mean_absolute_error: 0.5002 - val_gender_mean_squared_error: 0.2503
# Epoch 47/100
# 800/800 [==============================] - 1s 1ms/sample - loss: 21.1675 - age_loss: 47.9234 - income_loss: 2.3053 - gender_loss: 0.6953 - age_acc: 0.0000e+00 - age_mean_absolute_error: 5.9586 - age_mean_squared_error: 47.6352 - income_acc: 0.1275 - income_mean_absolute_error: 0.1798 - income_mean_squared_error: 0.0900 - gender_acc: 0.4825 - gender_mean_absolute_error: 0.5008 - gender_mean_squared_error: 0.2511 - val_loss: 20.9165 - val_age_loss: 43.0522 - val_income_loss: 2.3239 - val_gender_loss: 0.6942 - val_age_acc: 0.0000e+00 - val_age_mean_absolute_error: 5.7189 - val_age_mean_squared_error: 46.6570 - val_income_acc: 0.0800 - val_income_mean_absolute_error: 0.1801 - val_income_mean_squared_error: 0.0902 - val_gender_acc: 0.4550 - val_gender_mean_absolute_error: 0.5004 - val_gender_mean_squared_error: 0.2504
# Epoch 48/100
# 800/800 [==============================] - 1s 1ms/sample - loss: 21.1685 - age_loss: 47.6750 - income_loss: 2.3024 - gender_loss: 0.6956 - age_acc: 0.0000e+00 - age_mean_absolute_error: 5.9586 - age_mean_squared_error: 47.6409 - income_acc: 0.1100 - income_mean_absolute_error: 0.1798 - income_mean_squared_error: 0.0900 - gender_acc: 0.5000 - gender_mean_absolute_error: 0.5002 - gender_mean_squared_error: 0.2513 - val_loss: 20.9435 - val_age_loss: 49.7690 - val_income_loss: 2.3229 - val_gender_loss: 0.6944 - val_age_acc: 0.0000e+00 - val_age_mean_absolute_error: 5.7171 - val_age_mean_squared_error: 46.6306 - val_income_acc: 0.0800 - val_income_mean_absolute_error: 0.1801 - val_income_mean_squared_error: 0.0903 - val_gender_acc: 0.4550 - val_gender_mean_absolute_error: 0.5016 - val_gender_mean_squared_error: 0.2520
# Epoch 49/100
# 800/800 [==============================] - 1s 1ms/sample - loss: 21.1544 - age_loss: 47.6998 - income_loss: 2.3023 - gender_loss: 0.6941 - age_acc: 0.0000e+00 - age_mean_absolute_error: 5.9586 - age_mean_squared_error: 47.6357 - income_acc: 0.1088 - income_mean_absolute_error: 0.1799 - income_mean_squared_error: 0.0900 - gender_acc: 0.5075 - gender_mean_absolute_error: 0.5003 - gender_mean_squared_error: 0.2506 - val_loss: 20.8857 - val_age_loss: 47.8756 - val_income_loss: 2.3100 - val_gender_loss: 0.6899 - val_age_acc: 0.0000e+00 - val_age_mean_absolute_error: 5.7183 - val_age_mean_squared_error: 46.6485 - val_income_acc: 0.0800 - val_income_mean_absolute_error: 0.1801 - val_income_mean_squared_error: 0.0903 - val_gender_acc: 0.5450 - val_gender_mean_absolute_error: 0.4987 - val_gender_mean_squared_error: 0.2489
# Epoch 50/100
# 800/800 [==============================] - 1s 1ms/sample - loss: 21.1547 - age_loss: 47.4979 - income_loss: 2.3052 - gender_loss: 0.6941 - age_acc: 0.0000e+00 - age_mean_absolute_error: 5.9586 - age_mean_squared_error: 47.6416 - income_acc: 0.1275 - income_mean_absolute_error: 0.1798 - income_mean_squared_error: 0.0900 - gender_acc: 0.4775 - gender_mean_absolute_error: 0.5004 - gender_mean_squared_error: 0.2504 - val_loss: 20.8961 - val_age_loss: 49.2334 - val_income_loss: 2.3249 - val_gender_loss: 0.6940 - val_age_acc: 0.0000e+00 - val_age_mean_absolute_error: 5.7162 - val_age_mean_squared_error: 46.6190 - val_income_acc: 0.0800 - val_income_mean_absolute_error: 0.1801 - val_income_mean_squared_error: 0.0903 - val_gender_acc: 0.5450 - val_gender_mean_absolute_error: 0.4996 - val_gender_mean_squared_error: 0.2496
# Epoch 51/100
# 800/800 [==============================] - 1s 1ms/sample - loss: 21.1557 - age_loss: 47.7263 - income_loss: 2.3015 - gender_loss: 0.6945 - age_acc: 0.0000e+00 - age_mean_absolute_error: 5.9582 - age_mean_squared_error: 47.6347 - income_acc: 0.1275 - income_mean_absolute_error: 0.1798 - income_mean_squared_error: 0.0900 - gender_acc: 0.5000 - gender_mean_absolute_error: 0.5005 - gender_mean_squared_error: 0.2507 - val_loss: 20.9168 - val_age_loss: 47.5706 - val_income_loss: 2.3191 - val_gender_loss: 0.6955 - val_age_acc: 0.0000e+00 - val_age_mean_absolute_error: 5.7163 - val_age_mean_squared_error: 46.6197 - val_income_acc: 0.0800 - val_income_mean_absolute_error: 0.1801 - val_income_mean_squared_error: 0.0902 - val_gender_acc: 0.4550 - val_gender_mean_absolute_error: 0.5008 - val_gender_mean_squared_error: 0.2509
# Epoch 52/100
# 800/800 [==============================] - 1s 1ms/sample - loss: 21.1701 - age_loss: 47.6026 - income_loss: 2.2996 - gender_loss: 0.6960 - age_acc: 0.0000e+00 - age_mean_absolute_error: 5.9582 - age_mean_squared_error: 47.6358 - income_acc: 0.1275 - income_mean_absolute_error: 0.1798 - income_mean_squared_error: 0.0900 - gender_acc: 0.5000 - gender_mean_absolute_error: 0.5007 - gender_mean_squared_error: 0.2514 - val_loss: 20.9045 - val_age_loss: 44.7103 - val_income_loss: 2.3116 - val_gender_loss: 0.6934 - val_age_acc: 0.0000e+00 - val_age_mean_absolute_error: 5.7159 - val_age_mean_squared_error: 46.6147 - val_income_acc: 0.0800 - val_income_mean_absolute_error: 0.1802 - val_income_mean_squared_error: 0.0903 - val_gender_acc: 0.4550 - val_gender_mean_absolute_error: 0.5001 - val_gender_mean_squared_error: 0.2501
# Epoch 53/100
# 800/800 [==============================] - 1s 1ms/sample - loss: 21.1494 - age_loss: 47.4622 - income_loss: 2.3009 - gender_loss: 0.6938 - age_acc: 0.0000e+00 - age_mean_absolute_error: 5.9585 - age_mean_squared_error: 47.6390 - income_acc: 0.1275 - income_mean_absolute_error: 0.1798 - income_mean_squared_error: 0.0900 - gender_acc: 0.5050 - gender_mean_absolute_error: 0.5002 - gender_mean_squared_error: 0.2503 - val_loss: 20.9039 - val_age_loss: 47.4022 - val_income_loss: 2.3056 - val_gender_loss: 0.6924 - val_age_acc: 0.0000e+00 - val_age_mean_absolute_error: 5.7186 - val_age_mean_squared_error: 46.6530 - val_income_acc: 0.0800 - val_income_mean_absolute_error: 0.1802 - val_income_mean_squared_error: 0.0904 - val_gender_acc: 0.5450 - val_gender_mean_absolute_error: 0.4995 - val_gender_mean_squared_error: 0.2495
# Epoch 54/100
# 800/800 [==============================] - 1s 1ms/sample - loss: 21.1585 - age_loss: 47.7574 - income_loss: 2.3020 - gender_loss: 0.6951 - age_acc: 0.0000e+00 - age_mean_absolute_error: 5.9584 - age_mean_squared_error: 47.6346 - income_acc: 0.1275 - income_mean_absolute_error: 0.1798 - income_mean_squared_error: 0.0900 - gender_acc: 0.4675 - gender_mean_absolute_error: 0.5008 - gender_mean_squared_error: 0.2509 - val_loss: 20.8945 - val_age_loss: 46.3693 - val_income_loss: 2.3135 - val_gender_loss: 0.6911 - val_age_acc: 0.0000e+00 - val_age_mean_absolute_error: 5.7182 - val_age_mean_squared_error: 46.6475 - val_income_acc: 0.0800 - val_income_mean_absolute_error: 0.1801 - val_income_mean_squared_error: 0.0903 - val_gender_acc: 0.5450 - val_gender_mean_absolute_error: 0.4992 - val_gender_mean_squared_error: 0.2493
# Epoch 55/100
# 800/800 [==============================] - 1s 1ms/sample - loss: 21.1462 - age_loss: 47.4616 - income_loss: 2.3023 - gender_loss: 0.6933 - age_acc: 0.0000e+00 - age_mean_absolute_error: 5.9585 - age_mean_squared_error: 47.6354 - income_acc: 0.1275 - income_mean_absolute_error: 0.1798 - income_mean_squared_error: 0.0900 - gender_acc: 0.5025 - gender_mean_absolute_error: 0.5001 - gender_mean_squared_error: 0.2501 - val_loss: 20.9354 - val_age_loss: 41.9349 - val_income_loss: 2.3159 - val_gender_loss: 0.6969 - val_age_acc: 0.0000e+00 - val_age_mean_absolute_error: 5.7196 - val_age_mean_squared_error: 46.6677 - val_income_acc: 0.0800 - val_income_mean_absolute_error: 0.1802 - val_income_mean_squared_error: 0.0903 - val_gender_acc: 0.4550 - val_gender_mean_absolute_error: 0.5009 - val_gender_mean_squared_error: 0.2510
# Epoch 56/100
# 800/800 [==============================] - 1s 1ms/sample - loss: 21.1508 - age_loss: 47.7782 - income_loss: 2.3051 - gender_loss: 0.6939 - age_acc: 0.0000e+00 - age_mean_absolute_error: 5.9584 - age_mean_squared_error: 47.6338 - income_acc: 0.1275 - income_mean_absolute_error: 0.1798 - income_mean_squared_error: 0.0900 - gender_acc: 0.4900 - gender_mean_absolute_error: 0.5002 - gender_mean_squared_error: 0.2504 - val_loss: 20.9157 - val_age_loss: 45.7871 - val_income_loss: 2.3140 - val_gender_loss: 0.6931 - val_age_acc: 0.0000e+00 - val_age_mean_absolute_error: 5.7188 - val_age_mean_squared_error: 46.6561 - val_income_acc: 0.0800 - val_income_mean_absolute_error: 0.1802 - val_income_mean_squared_error: 0.0905 - val_gender_acc: 0.5450 - val_gender_mean_absolute_error: 0.4998 - val_gender_mean_squared_error: 0.2498
# Epoch 57/100
# 800/800 [==============================] - 1s 1ms/sample - loss: 21.1574 - age_loss: 47.5196 - income_loss: 2.3027 - gender_loss: 0.6945 - age_acc: 0.0000e+00 - age_mean_absolute_error: 5.9585 - age_mean_squared_error: 47.6379 - income_acc: 0.1275 - income_mean_absolute_error: 0.1798 - income_mean_squared_error: 0.0900 - gender_acc: 0.4750 - gender_mean_absolute_error: 0.5005 - gender_mean_squared_error: 0.2507 - val_loss: 20.8943 - val_age_loss: 42.5151 - val_income_loss: 2.2963 - val_gender_loss: 0.6918 - val_age_acc: 0.0000e+00 - val_age_mean_absolute_error: 5.7179 - val_age_mean_squared_error: 46.6426 - val_income_acc: 0.0800 - val_income_mean_absolute_error: 0.1801 - val_income_mean_squared_error: 0.0902 - val_gender_acc: 0.5450 - val_gender_mean_absolute_error: 0.4995 - val_gender_mean_squared_error: 0.2495
# Epoch 58/100
# ...
# Epoch 82/100
# 800/800 [==============================] - 1s 1ms/sample - loss: 21.1547 - age_loss: 47.7006 - income_loss: 2.3045 - gender_loss: 0.6941 - age_acc: 0.0000e+00 - age_mean_absolute_error: 5.9583 - age_mean_squared_error: 47.6341 - income_acc: 0.1275 - income_mean_absolute_error: 0.1798 - income_mean_squared_error: 0.0900 - gender_acc: 0.4850 - gender_mean_absolute_error: 0.5004 - gender_mean_squared_error: 0.2505 - val_loss: 20.8916 - val_age_loss: 44.1799 - val_income_loss: 2.3045 - val_gender_loss: 0.6913 - val_age_acc: 0.0000e+00 - val_age_mean_absolute_error: 5.7173 - val_age_mean_squared_error: 46.6343 - val_income_acc: 0.0800 - val_income_mean_absolute_error: 0.1801 - val_income_mean_squared_error: 0.0903 - val_gender_acc: 0.5450 - val_gender_mean_absolute_error: 0.4993 - val_gender_mean_squared_error: 0.2493
# Epoch 83/100
# 800/800 [==============================] - 1s 1ms/sample - loss: 21.1833 - age_loss: 47.7339 - income_loss: 2.3046 - gender_loss: 0.6973 - age_acc: 0.0000e+00 - age_mean_absolute_error: 5.9584 - age_mean_squared_error: 47.6345 - income_acc: 0.1275 - income_mean_absolute_error: 0.1798 - income_mean_squared_error: 0.0900 - gender_acc: 0.4775 - gender_mean_absolute_error: 0.5012 - gender_mean_squared_error: 0.2520 - val_loss: 20.9322 - val_age_loss: 44.6540 - val_income_loss: 2.3167 - val_gender_loss: 0.6963 - val_age_acc: 0.0000e+00 - val_age_mean_absolute_error: 5.7176 - val_age_mean_squared_error: 46.6378 - val_income_acc: 0.0800 - val_income_mean_absolute_error: 0.1801 - val_income_mean_squared_error: 0.0903 - val_gender_acc: 0.4550 - val_gender_mean_absolute_error: 0.5010 - val_gender_mean_squared_error: 0.2512
# Epoch 84/100
# 800/800 [==============================] - 1s 1ms/sample - loss: 21.1737 - age_loss: 46.9768 - income_loss: 2.3002 - gender_loss: 0.6974 - age_acc: 0.0000e+00 - age_mean_absolute_error: 5.9583 - age_mean_squared_error: 47.6332 - income_acc: 0.1200 - income_mean_absolute_error: 0.1798 - income_mean_squared_error: 0.0900 - gender_acc: 0.4800 - gender_mean_absolute_error: 0.5009 - gender_mean_squared_error: 0.2517 - val_loss: 20.8776 - val_age_loss: 45.3146 - val_income_loss: 2.3063 - val_gender_loss: 0.6911 - val_age_acc: 0.0000e+00 - val_age_mean_absolute_error: 5.7177 - val_age_mean_squared_error: 46.6397 - val_income_acc: 0.0800 - val_income_mean_absolute_error: 0.1801 - val_income_mean_squared_error: 0.0903 - val_gender_acc: 0.5450 - val_gender_mean_absolute_error: 0.4981 - val_gender_mean_squared_error: 0.2485
# Epoch 85/100
# 800/800 [==============================] - 1s 1ms/sample - loss: 21.1558 - age_loss: 47.4410 - income_loss: 2.3057 - gender_loss: 0.6942 - age_acc: 0.0000e+00 - age_mean_absolute_error: 5.9586 - age_mean_squared_error: 47.6398 - income_acc: 0.1275 - income_mean_absolute_error: 0.1798 - income_mean_squared_error: 0.0900 - gender_acc: 0.5075 - gender_mean_absolute_error: 0.5003 - gender_mean_squared_error: 0.2505 - val_loss: 20.9343 - val_age_loss: 43.6469 - val_income_loss: 2.2950 - val_gender_loss: 0.6939 - val_age_acc: 0.0000e+00 - val_age_mean_absolute_error: 5.7183 - val_age_mean_squared_error: 46.6481 - val_income_acc: 0.0800 - val_income_mean_absolute_error: 0.1801 - val_income_mean_squared_error: 0.0903 - val_gender_acc: 0.4550 - val_gender_mean_absolute_error: 0.5012 - val_gender_mean_squared_error: 0.2514
# Epoch 86/100
# 800/800 [==============================] - 1s 1ms/sample - loss: 21.1588 - age_loss: 48.0364 - income_loss: 2.3046 - gender_loss: 0.6944 - age_acc: 0.0000e+00 - age_mean_absolute_error: 5.9586 - age_mean_squared_error: 47.6428 - income_acc: 0.1213 - income_mean_absolute_error: 0.1797 - income_mean_squared_error: 0.0900 - gender_acc: 0.4825 - gender_mean_absolute_error: 0.5006 - gender_mean_squared_error: 0.2507 - val_loss: 20.9058 - val_age_loss: 47.2718 - val_income_loss: 2.3149 - val_gender_loss: 0.6921 - val_age_acc: 0.0000e+00 - val_age_mean_absolute_error: 5.7164 - val_age_mean_squared_error: 46.6216 - val_income_acc: 0.1050 - val_income_mean_absolute_error: 0.1802 - val_income_mean_squared_error: 0.0904 - val_gender_acc: 0.5450 - val_gender_mean_absolute_error: 0.4997 - val_gender_mean_squared_error: 0.2497
# Epoch 87/100
# 800/800 [==============================] - 1s 1ms/sample - loss: 21.1464 - age_loss: 47.7352 - income_loss: 2.3008 - gender_loss: 0.6935 - age_acc: 0.0000e+00 - age_mean_absolute_error: 5.9583 - age_mean_squared_error: 47.6369 - income_acc: 0.1125 - income_mean_absolute_error: 0.1798 - income_mean_squared_error: 0.0900 - gender_acc: 0.4900 - gender_mean_absolute_error: 0.5002 - gender_mean_squared_error: 0.2502 - val_loss: 20.9123 - val_age_loss: 47.9651 - val_income_loss: 2.3129 - val_gender_loss: 0.6955 - val_age_acc: 0.0000e+00 - val_age_mean_absolute_error: 5.7167 - val_age_mean_squared_error: 46.6254 - val_income_acc: 0.0800 - val_income_mean_absolute_error: 0.1800 - val_income_mean_squared_error: 0.0901 - val_gender_acc: 0.4550 - val_gender_mean_absolute_error: 0.5008 - val_gender_mean_squared_error: 0.2509
# Epoch 88/100
# 800/800 [==============================] - 1s 1ms/sample - loss: 21.1533 - age_loss: 47.4895 - income_loss: 2.3038 - gender_loss: 0.6939 - age_acc: 0.0000e+00 - age_mean_absolute_error: 5.9587 - age_mean_squared_error: 47.6397 - income_acc: 0.1275 - income_mean_absolute_error: 0.1798 - income_mean_squared_error: 0.0900 - gender_acc: 0.5000 - gender_mean_absolute_error: 0.5003 - gender_mean_squared_error: 0.2504 - val_loss: 20.9265 - val_age_loss: 44.9120 - val_income_loss: 2.3157 - val_gender_loss: 0.6954 - val_age_acc: 0.0000e+00 - val_age_mean_absolute_error: 5.7171 - val_age_mean_squared_error: 46.6318 - val_income_acc: 0.0800 - val_income_mean_absolute_error: 0.1801 - val_income_mean_squared_error: 0.0904 - val_gender_acc: 0.4550 - val_gender_mean_absolute_error: 0.5008 - val_gender_mean_squared_error: 0.2508
# Epoch 89/100
# 800/800 [==============================] - 1s 1ms/sample - loss: 21.1490 - age_loss: 47.6333 - income_loss: 2.3040 - gender_loss: 0.6936 - age_acc: 0.0000e+00 - age_mean_absolute_error: 5.9583 - age_mean_squared_error: 47.6424 - income_acc: 0.1125 - income_mean_absolute_error: 0.1798 - income_mean_squared_error: 0.0900 - gender_acc: 0.5000 - gender_mean_absolute_error: 0.5001 - gender_mean_squared_error: 0.2501 - val_loss: 20.8808 - val_age_loss: 42.2294 - val_income_loss: 2.3026 - val_gender_loss: 0.6910 - val_age_acc: 0.0000e+00 - val_age_mean_absolute_error: 5.7149 - val_age_mean_squared_error: 46.6013 - val_income_acc: 0.0800 - val_income_mean_absolute_error: 0.1801 - val_income_mean_squared_error: 0.0902 - val_gender_acc: 0.5450 - val_gender_mean_absolute_error: 0.4992 - val_gender_mean_squared_error: 0.2493
# Epoch 90/100
# 800/800 [==============================] - 1s 1ms/sample - loss: 21.1476 - age_loss: 47.9805 - income_loss: 2.3032 - gender_loss: 0.6939 - age_acc: 0.0000e+00 - age_mean_absolute_error: 5.9582 - age_mean_squared_error: 47.6323 - income_acc: 0.1275 - income_mean_absolute_error: 0.1799 - income_mean_squared_error: 0.0900 - gender_acc: 0.4850 - gender_mean_absolute_error: 0.5002 - gender_mean_squared_error: 0.2502 - val_loss: 20.9306 - val_age_loss: 47.7720 - val_income_loss: 2.3290 - val_gender_loss: 0.6964 - val_age_acc: 0.0000e+00 - val_age_mean_absolute_error: 5.7171 - val_age_mean_squared_error: 46.6314 - val_income_acc: 0.0800 - val_income_mean_absolute_error: 0.1801 - val_income_mean_squared_error: 0.0903 - val_gender_acc: 0.4550 - val_gender_mean_absolute_error: 0.5011 - val_gender_mean_squared_error: 0.2512
# Epoch 91/100
# 800/800 [==============================] - 1s 1ms/sample - loss: 21.1538 - age_loss: 47.2116 - income_loss: 2.3031 - gender_loss: 0.6940 - age_acc: 0.0000e+00 - age_mean_absolute_error: 5.9587 - age_mean_squared_error: 47.6407 - income_acc: 0.1275 - income_mean_absolute_error: 0.1797 - income_mean_squared_error: 0.0900 - gender_acc: 0.4625 - gender_mean_absolute_error: 0.5004 - gender_mean_squared_error: 0.2504 - val_loss: 20.9185 - val_age_loss: 44.0630 - val_income_loss: 2.3173 - val_gender_loss: 0.6933 - val_age_acc: 0.0000e+00 - val_age_mean_absolute_error: 5.7196 - val_age_mean_squared_error: 46.6683 - val_income_acc: 0.0800 - val_income_mean_absolute_error: 0.1801 - val_income_mean_squared_error: 0.0903 - val_gender_acc: 0.4550 - val_gender_mean_absolute_error: 0.5001 - val_gender_mean_squared_error: 0.2501
# Epoch 92/100
# 800/800 [==============================] - 1s 1ms/sample - loss: 21.1530 - age_loss: 47.8927 - income_loss: 2.3056 - gender_loss: 0.6935 - age_acc: 0.0000e+00 - age_mean_absolute_error: 5.9594 - age_mean_squared_error: 47.6532 - income_acc: 0.1225 - income_mean_absolute_error: 0.1799 - income_mean_squared_error: 0.0900 - gender_acc: 0.4825 - gender_mean_absolute_error: 0.5002 - gender_mean_squared_error: 0.2502 - val_loss: 20.9064 - val_age_loss: 44.9321 - val_income_loss: 2.3177 - val_gender_loss: 0.6926 - val_age_acc: 0.0000e+00 - val_age_mean_absolute_error: 5.7206 - val_age_mean_squared_error: 46.6847 - val_income_acc: 0.1050 - val_income_mean_absolute_error: 0.1800 - val_income_mean_squared_error: 0.0902 - val_gender_acc: 0.5450 - val_gender_mean_absolute_error: 0.4997 - val_gender_mean_squared_error: 0.2497
# Epoch 93/100
# 800/800 [==============================] - 1s 1ms/sample - loss: 21.1615 - age_loss: 47.8262 - income_loss: 2.3070 - gender_loss: 0.6942 - age_acc: 0.0000e+00 - age_mean_absolute_error: 5.9586 - age_mean_squared_error: 47.6430 - income_acc: 0.1262 - income_mean_absolute_error: 0.1799 - income_mean_squared_error: 0.0901 - gender_acc: 0.4650 - gender_mean_absolute_error: 0.5005 - gender_mean_squared_error: 0.2505 - val_loss: 20.9000 - val_age_loss: 42.4121 - val_income_loss: 2.3135 - val_gender_loss: 0.6933 - val_age_acc: 0.0000e+00 - val_age_mean_absolute_error: 5.7145 - val_age_mean_squared_error: 46.5968 - val_income_acc: 0.0800 - val_income_mean_absolute_error: 0.1801 - val_income_mean_squared_error: 0.0904 - val_gender_acc: 0.4550 - val_gender_mean_absolute_error: 0.5000 - val_gender_mean_squared_error: 0.2500
# Epoch 94/100
# 800/800 [==============================] - 1s 1ms/sample - loss: 21.1441 - age_loss: 47.9103 - income_loss: 2.2987 - gender_loss: 0.6935 - age_acc: 0.0000e+00 - age_mean_absolute_error: 5.9581 - age_mean_squared_error: 47.6366 - income_acc: 0.1275 - income_mean_absolute_error: 0.1798 - income_mean_squared_error: 0.0899 - gender_acc: 0.4700 - gender_mean_absolute_error: 0.5002 - gender_mean_squared_error: 0.2502 - val_loss: 20.9072 - val_age_loss: 45.9151 - val_income_loss: 2.3329 - val_gender_loss: 0.6934 - val_age_acc: 0.0000e+00 - val_age_mean_absolute_error: 5.7148 - val_age_mean_squared_error: 46.5999 - val_income_acc: 0.0800 - val_income_mean_absolute_error: 0.1801 - val_income_mean_squared_error: 0.0902 - val_gender_acc: 0.4550 - val_gender_mean_absolute_error: 0.5005 - val_gender_mean_squared_error: 0.2505
# Epoch 95/100
# 800/800 [==============================] - 1s 1ms/sample - loss: 21.1482 - age_loss: 47.8876 - income_loss: 2.3025 - gender_loss: 0.6935 - age_acc: 0.0000e+00 - age_mean_absolute_error: 5.9583 - age_mean_squared_error: 47.6402 - income_acc: 0.1200 - income_mean_absolute_error: 0.1798 - income_mean_squared_error: 0.0900 - gender_acc: 0.5000 - gender_mean_absolute_error: 0.5001 - gender_mean_squared_error: 0.2502 - val_loss: 20.9125 - val_age_loss: 44.3031 - val_income_loss: 2.3207 - val_gender_loss: 0.6940 - val_age_acc: 0.0000e+00 - val_age_mean_absolute_error: 5.7149 - val_age_mean_squared_error: 46.6013 - val_income_acc: 0.0800 - val_income_mean_absolute_error: 0.1802 - val_income_mean_squared_error: 0.0905 - val_gender_acc: 0.4550 - val_gender_mean_absolute_error: 0.5003 - val_gender_mean_squared_error: 0.2503
# Epoch 96/100
# 800/800 [==============================] - 1s 1ms/sample - loss: 21.1507 - age_loss: 47.3737 - income_loss: 2.3023 - gender_loss: 0.6941 - age_acc: 0.0000e+00 - age_mean_absolute_error: 5.9581 - age_mean_squared_error: 47.6353 - income_acc: 0.1275 - income_mean_absolute_error: 0.1797 - income_mean_squared_error: 0.0900 - gender_acc: 0.4900 - gender_mean_absolute_error: 0.5003 - gender_mean_squared_error: 0.2504 - val_loss: 20.8868 - val_age_loss: 53.8475 - val_income_loss: 2.3213 - val_gender_loss: 0.6931 - val_age_acc: 0.0000e+00 - val_age_mean_absolute_error: 5.7156 - val_age_mean_squared_error: 46.6112 - val_income_acc: 0.0800 - val_income_mean_absolute_error: 0.1802 - val_income_mean_squared_error: 0.0904 - val_gender_acc: 0.5450 - val_gender_mean_absolute_error: 0.4990 - val_gender_mean_squared_error: 0.2491
# Epoch 97/100
# 800/800 [==============================] - 1s 1ms/sample - loss: 21.1457 - age_loss: 47.5965 - income_loss: 2.3046 - gender_loss: 0.6934 - age_acc: 0.0000e+00 - age_mean_absolute_error: 5.9584 - age_mean_squared_error: 47.6385 - income_acc: 0.1275 - income_mean_absolute_error: 0.1798 - income_mean_squared_error: 0.0900 - gender_acc: 0.4900 - gender_mean_absolute_error: 0.5000 - gender_mean_squared_error: 0.2500 - val_loss: 20.9150 - val_age_loss: 42.1023 - val_income_loss: 2.3051 - val_gender_loss: 0.6914 - val_age_acc: 0.0000e+00 - val_age_mean_absolute_error: 5.7161 - val_age_mean_squared_error: 46.6172 - val_income_acc: 0.0800 - val_income_mean_absolute_error: 0.1800 - val_income_mean_squared_error: 0.0901 - val_gender_acc: 0.4550 - val_gender_mean_absolute_error: 0.5009 - val_gender_mean_squared_error: 0.2510
# Epoch 98/100
# 800/800 [==============================] - 1s 1ms/sample - loss: 21.1568 - age_loss: 47.2633 - income_loss: 2.3084 - gender_loss: 0.6939 - age_acc: 0.0000e+00 - age_mean_absolute_error: 5.9586 - age_mean_squared_error: 47.6426 - income_acc: 0.1275 - income_mean_absolute_error: 0.1800 - income_mean_squared_error: 0.0901 - gender_acc: 0.4875 - gender_mean_absolute_error: 0.5003 - gender_mean_squared_error: 0.2504 - val_loss: 20.9059 - val_age_loss: 50.1017 - val_income_loss: 2.3200 - val_gender_loss: 0.6927 - val_age_acc: 0.0000e+00 - val_age_mean_absolute_error: 5.7181 - val_age_mean_squared_error: 46.6451 - val_income_acc: 0.0800 - val_income_mean_absolute_error: 0.1801 - val_income_mean_squared_error: 0.0903 - val_gender_acc: 0.5450 - val_gender_mean_absolute_error: 0.4998 - val_gender_mean_squared_error: 0.2499
# Epoch 99/100
# 800/800 [==============================] - 1s 1ms/sample - loss: 21.1629 - age_loss: 47.8416 - income_loss: 2.3015 - gender_loss: 0.6953 - age_acc: 0.0000e+00 - age_mean_absolute_error: 5.9583 - age_mean_squared_error: 47.6354 - income_acc: 0.1175 - income_mean_absolute_error: 0.1798 - income_mean_squared_error: 0.0900 - gender_acc: 0.4700 - gender_mean_absolute_error: 0.5009 - gender_mean_squared_error: 0.2511 - val_loss: 20.8834 - val_age_loss: 48.4380 - val_income_loss: 2.3164 - val_gender_loss: 0.6901 - val_age_acc: 0.0000e+00 - val_age_mean_absolute_error: 5.7156 - val_age_mean_squared_error: 46.6112 - val_income_acc: 0.0800 - val_income_mean_absolute_error: 0.1801 - val_income_mean_squared_error: 0.0904 - val_gender_acc: 0.5450 - val_gender_mean_absolute_error: 0.4988 - val_gender_mean_squared_error: 0.2489
# Epoch 100/100
# 800/800 [==============================] - 1s 1ms/sample - loss: 21.1499 - age_loss: 48.0429 - income_loss: 2.3011 - gender_loss: 0.6940 - age_acc: 0.0000e+00 - age_mean_absolute_error: 5.9580 - age_mean_squared_error: 47.6351 - income_acc: 0.1100 - income_mean_absolute_error: 0.1798 - income_mean_squared_error: 0.0900 - gender_acc: 0.4975 - gender_mean_absolute_error: 0.5003 - gender_mean_squared_error: 0.2504 - val_loss: 20.9081 - val_age_loss: 47.6084 - val_income_loss: 2.3029 - val_gender_loss: 0.6935 - val_age_acc: 0.0000e+00 - val_age_mean_absolute_error: 5.7175 - val_age_mean_squared_error: 46.6364 - val_income_acc: 0.0800 - val_income_mean_absolute_error: 0.1801 - val_income_mean_squared_error: 0.0902 - val_gender_acc: 0.4550 - val_gender_mean_absolute_error: 0.5002 - val_gender_mean_squared_error: 0.2502

# %% [markdown]
# ## 9. 使用matplotlib显示结果

# %% [markdown]
# ### 9.1 整体损失

# %%
    hist = pd.DataFrame(history.history)
    hist['epoch'] = history.epoch

    plt.figure(figsize=(15, 2))
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.plot(hist['epoch'], hist['loss'], label='loss')
    plt.plot(hist['epoch'], hist['val_loss'], label = 'val_loss')
    plt.legend()
    plt.show()

# %% [markdown]
# ### 9.2 年龄推测（回归问题）
#
# 回归问题不存在精度的概念，因此第一张图精度总是0，MAE或者MSE是回归问题主要参考指标

# %%
# ------------------------------------- Age ------------------------------------- 
    plt.figure(figsize=(15, 2))
    plt.xlabel('Epoch')
    plt.ylabel('Age Accuracy')
    plt.plot(hist['epoch'], hist['age_acc'], label='age_acc')
    plt.plot(hist['epoch'], hist['val_age_acc'], label = 'val_age_acc')
    plt.legend()
    
    plt.figure(figsize=(15, 2))
    plt.xlabel('Epoch')
    plt.ylabel('Age Loss')
    plt.plot(hist['epoch'], hist['age_loss'], label='age_loss')
    plt.plot(hist['epoch'], hist['val_age_loss'], label = 'val_age_loss')
    plt.legend()
    
    plt.figure(figsize=(15, 2))
    plt.xlabel('Epoch')
    plt.ylabel('Age Mean Absolute Error')
    plt.plot(hist['epoch'], hist['age_mean_absolute_error'], label='age_mean_absolute_error')
    plt.plot(hist['epoch'], hist['val_age_mean_absolute_error'], label = 'val_age_mean_absolute_error')
    plt.legend()
    
    plt.figure(figsize=(15, 2))
    plt.xlabel('Epoch')
    plt.ylabel('Age Mean Absolute Error')
    plt.plot(hist['epoch'], hist['age_mean_absolute_error'], label='age_mean_absolute_error')
    plt.plot(hist['epoch'], hist['val_age_mean_absolute_error'], label = 'val_age_mean_absolute_error')
    plt.legend()
    
    plt.figure(figsize=(15, 2))
    plt.xlabel('Epoch')
    plt.ylabel('Age Mean Squared Error')
    plt.plot(hist['epoch'], hist['age_mean_squared_error'], label='age_mean_squared_error')
    plt.plot(hist['epoch'], hist['val_age_mean_squared_error'], label = 'val_age_mean_squared_error')
    plt.legend()
    
    plt.show()

# %% [markdown]
# ### 9.3 收入区间推测（多分类问题）
#
# 因为是随机数，并且总类别为10，因此在这种情况下acc约等于10%， MAE和MSE不具有参考价值

# %%
   
    # ------------------------------------- income ------------------------------------- 
    plt.figure(figsize=(15, 2))
    plt.xlabel('Epoch')
    plt.ylabel('Income accuracy')
    plt.plot(hist['epoch'], hist['income_acc'], label='income_acc')
    plt.plot(hist['epoch'], hist['val_income_acc'], label = 'val_income_acc')
    plt.legend()
    
    plt.figure(figsize=(15, 2))
    plt.xlabel('Epoch')
    plt.ylabel('Income Loss')
    plt.plot(hist['epoch'], hist['income_loss'], label='income_loss')
    plt.plot(hist['epoch'], hist['val_income_loss'], label = 'val_income_loss')
    plt.legend()
    
    plt.figure(figsize=(15, 2))
    plt.xlabel('Epoch')
    plt.ylabel('Income Mean Absolute Error')
    plt.plot(hist['epoch'], hist['income_mean_absolute_error'], label='income_mean_absolute_error')
    plt.plot(hist['epoch'], hist['val_income_mean_absolute_error'], label = 'val_income_mean_absolute_error')
    plt.legend()
    
    plt.figure(figsize=(15, 2))
    plt.xlabel('Epoch')
    plt.ylabel('Income Mean Absolute Error')
    plt.plot(hist['epoch'], hist['income_mean_absolute_error'], label='income_mean_absolute_error')
    plt.plot(hist['epoch'], hist['val_income_mean_absolute_error'], label = 'val_income_mean_absolute_error')
    plt.legend()
    
    plt.figure(figsize=(15, 2))
    plt.xlabel('Epoch')
    plt.ylabel('Income Mean Squared Error')
    plt.plot(hist['epoch'], hist['income_mean_squared_error'], label='income_mean_squared_error')
    plt.plot(hist['epoch'], hist['val_income_mean_squared_error'], label = 'val_income_mean_squared_error')
    plt.legend()
    
    plt.show()

# %% [markdown]
# ### 9.4 性别推测（二分类问题）
#
# 随机数下，二分类问题， acc约等于50%，MAE和MSE不具有参考价值

# %%
  # ------------------------------------- income ------------------------------------- 
    plt.figure(figsize=(15, 2))
    plt.xlabel('Epoch')
    plt.ylabel('Gender Accuracy')
    plt.plot(hist['epoch'], hist['gender_acc'], label='gender_acc')
    plt.plot(hist['epoch'], hist['val_gender_acc'], label = 'val_gender_acc')
    plt.legend()
    
    plt.figure(figsize=(15, 2))
    plt.xlabel('Epoch')
    plt.ylabel('Gender Loss')
    plt.plot(hist['epoch'], hist['gender_loss'], label='gender_loss')
    plt.plot(hist['epoch'], hist['val_gender_loss'], label = 'val_gender_loss')
    plt.legend()
    
    plt.figure(figsize=(15, 2))
    plt.xlabel('Epoch')
    plt.ylabel('Gender Mean Absolute Error')
    plt.plot(hist['epoch'], hist['gender_mean_absolute_error'], label='gender_mean_absolute_error')
    plt.plot(hist['epoch'], hist['val_gender_mean_absolute_error'], label = 'val_gender_mean_absolute_error')
    plt.legend()
    
    plt.figure(figsize=(15, 2))
    plt.xlabel('Epoch')
    plt.ylabel('Gender Mean Absolute Error')
    plt.plot(hist['epoch'], hist['gender_mean_absolute_error'], label='gender_mean_absolute_error')
    plt.plot(hist['epoch'], hist['val_gender_mean_absolute_error'], label = 'val_gender_mean_absolute_error')
    plt.legend()
    
    plt.figure(figsize=(15, 2))
    plt.xlabel('Epoch')
    plt.ylabel('Gender Mean Squared Error')
    plt.plot(hist['epoch'], hist['gender_mean_squared_error'], label='gender_mean_squared_error')
    plt.plot(hist['epoch'], hist['val_gender_mean_squared_error'], label = 'val_gender_mean_squared_error')
    plt.legend()
    
    plt.show()
